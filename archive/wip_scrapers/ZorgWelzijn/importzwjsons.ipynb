# %%
import pandas as pd

# %%
df = pd.read_json("Aandelen_2024Q4 (1).json")

# %%
df
# Out:
#                        Onderneming                 Land  \
# 0                           1&1 AG            Duitsland
# 1     360 SECURITY TECHNOLOGY IN-A                China
# 2     37 INTERACTIVE ENTERTAINME-A                China
# 3                     3I GROUP PLC  Verenigd Koninkrijk
# 4                     3M INDIA LTD                India
# ...                            ...                  ...
# 3879                   ZSCALER INC     Verenigde Staten
# 3880                    ZTE CORP-A                China
# 3881                    ZTE CORP-H                China
# 3882     ZURICH INSURANCE GROUP AG          Zwitserland
# 3883        ZYDUS LIFESCIENCES LTD                India
#
#                                                  Sector  BelangEur
# 0                              Telecommunicatiediensten     268859
# 1                                   Software & Diensten     722465
# 2                                 Media & Entertainment     319282
# ...

# %%
df = df.rename(columns={"Onderneming": "Naam"})

# %%
df2 = pd.read_json("Obligaties_2024Q4.json")

# %%
df3 = pd.merge(df, df2, "outer")

# %%
df3
# Out:
#                               Naam                 Land  \
# 0                           1&1 AG            Duitsland
# 1     360 SECURITY TECHNOLOGY IN-A                China
# 2     37 INTERACTIVE ENTERTAINME-A                China
# 3                        3Cime S.A               Italie
# 4                     3I GROUP PLC  Verenigd Koninkrijk
# ...                            ...                  ...
# 5449             de Volksbank N.V.            Nederland
# 5450                   goeasy Ltd.               Canada
# 5451             iHeartMedia, Inc.     Verenigde Staten
# 5452               loanDepot, Inc.     Verenigde Staten
# 5453                    Ørsted A/S           Denemarken
#
#                               Sector  BelangEur
# 0           Telecommunicatiediensten     268859
# 1                Software & Diensten     722465
# 2              Media & Entertainment     319282
# 3                    Gezondheidszorg     661599
# ...

# %%
df3.to_clipboard()
