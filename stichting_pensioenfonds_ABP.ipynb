# %%
import pdfplumber
import pandas as pd

# %%
pdf = pdfplumber.open("stichting_pensioenfonds_ABP.pdf")

# %%
tabs = []

for page in pdf.pages:
    tabs.append(page.extract_tables(table_settings={"vertical_strategy": "lines", "join_y_tolerance": 50}))

tabs
# Out:
# [[[['Beursgenoteerde', ''], ['beleggingen', None]]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['', ''],
#    ['Afrika', '625'],
#    ['Zuid-Afrika', '625'],
#    ['Absa Group Ltd', '5'],
#    ['Anglo American Platinum Ltd', '1'],
#    ['Anglogold Ashanti Plc', '29'],
#    ['Aspen Pharmacare Holdings Ltd', '1'],
#    ['AVI Ltd', '7'],
#    ['Bid Corp Ltd', '8'],
#    ['Bidvest Group Ltd', '1'],
#    ['Capitec Bank Holdings Ltd', '55'],
#    ['Clicks Group Ltd', '25'],
#    ['Discovery Ltd', '5'],
#    ['FirstRand Ltd', '90'],
#    ['Foschini Group Ltd', '1'],
#    ['Gold Fields Ltd', '85'],
#    ['Hyprop Investments Ltd', '2'],
#    ['Impala Platinum Holdings Ltd', '32'],
#    ['Investec Ltd', '8'],
#    ['Life Healthcare Group Holdings Ltd', '1'],
#    ['Momentum Group Ltd', '2'],
#    ['Mr Price Group Ltd', '9'],
#    ['MTN Group Ltd', '17'],
#    ['Naspers Ltd', '117'],
#    ['Nedbank Group Ltd', '6'],
#    ['NEPI Rockcastle NV', '4'],
#    ['Old Mutual Ltd', '5']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Omnia Holdings Ltd', '1'],
#    ['OUTsurance Group Ltd', '16'],
#    ['Remgro Ltd', '1'],
#    ['Sanlam Ltd', '34'],
#    ['Sappi Ltd', '2'],
#    ['Shoprite Holdings Ltd', '33'],
#    ['Standard Bank Group Ltd', '22'],
#    ['Telkom SA SOC Ltd', '1'],
#    ['Vodacom Group Ltd', '1'],
#    ['Vukile Property Fund Ltd', '1'],
#    ['Woolworths Holdings Ltd/South Africa', '1'],
#    ['Azië', '34.689'],
#    ['China', '8.307'],
#    ['3SBio Inc', '6'],
#    ['AAC Technologies Holdings Inc', '19'],
#    ['Agricultural Bank of China Ltd', '60'],
#    ['Akeso Inc', '1'],
#    ['Alibaba Group Holding Ltd', '586'],
#    ['Anhui Conch Cement Co Ltd', '10'],
#    ['Anker Innovations Technology Co Ltd', '10'],
#    ['Atour Lifestyle Holdings Ltd', '17'],
#    ['Autohome Inc', '25'],
#    ['Baidu Inc', '54'],
#    ['Bank of China \xad Luxembourg Branch', '41'],
#    ['Bank of Communications Co Ltd', '2']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Bank of Ningbo Co Ltd', '3'],
#    ['BeiGene Ltd', '2'],
#    ['Beijing Jingneng Clean Energy Co Ltd', '1'],
#    ['Beijing Kingsoft Office Software Inc', '1'],
#    ['Beijing New Building Materials PLC', '5'],
#    ['Beijing Oriental Yuhong Waterproof Technology Co Ltd', '15'],
#    ['Bilibili Inc', '13'],
#    ['BOC Aviation Ltd', '2'],
#    ['BOE Technology Group Co Ltd', '31'],
#    ['Bosideng International Holdings Ltd', '31'],
#    ['Centre Testing International Group Co Ltd', '26'],
#    ['CGN Power Co Ltd', '1'],
#    ['China BlueChemical Ltd', '4'],
#    ['China CITIC Bank Corp Ltd', '6'],
#    ['China Communications Services Corp Ltd', '2'],
#    ['China Construction Bank Corp', '242'],
#    ['China CSSC Holdings Ltd', '2'],
#    ['China Everbright Bank Co Ltd', '6'],
#    ['China Feihe Ltd', '6'],
#    ['China Galaxy Securities Co Ltd', '8'],
#    ['China Hongqiao Group Ltd', '13'],
#    ['China International Capital Corp Ltd', '16'],
#    ['China International Marine Containers Group Co Ltd', '1'],
#    ['China Life Insurance Co Ltd', '9'],
#    ['China Medical System Holdings Ltd', '7'],
#    ['China Meidong Auto Holdings Ltd', '4'],
#    ['China Mengniu Dairy Co Ltd', '17'],
#    ['China Merchants Bank Co Ltd', '179']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['China Merchants Shekou Industrial Zone Holdings Co Ltd', '8'],
#    ['China Minsheng Banking Corp Ltd', '1'],
#    ['China Nonferrous Mining Corp Ltd', '2'],
#    ['China Overseas Land & Investment Ltd', '72'],
#    ['China Overseas Property Holdings Ltd', '1'],
#    ['China Pacific Insurance Group Co Ltd', '51'],
#    ['China Railway Group Ltd', '1'],
#    ['China Resources Beer Holdings Co Ltd', '52'],
#    ['China Resources Beverage Holdings Co Ltd', '10'],
#    ['China Resources Gas Group Ltd', '12'],
#    ['China Resources Land Ltd', '470'],
#    ['China Resources Mixc Lifestyle Services Ltd', '3'],
#    ['China South Publishing & Media Group Co Ltd', '8'],
#    ['China State Construction International Holdings Ltd', '1'],
#    ['China Taiping Insurance Holdings Co Ltd', '13'],
#    ['China Tower Corp Ltd', '8'],
#    ['China Yangtze Power Co Ltd', '31'],
#    ['Chongqing Rural Commercial Bank Co Ltd', '6'],
#    ['Chow Tai Fook Jewellery Group Ltd', '4'],
#    ['CITIC Securities Co Ltd', '3'],
#    ['CMOC Group Ltd', '20'],
#    ['Consun Pharmaceutical Group Ltd', '7'],
#    ['Contemporary Amperex Technology Co Ltd', '283'],
#    ['COSCO SHIPPING Holdings Co Ltd', '1'],
#    ['Country Garden Services Holdings Co Ltd', '4'],
#    ['CRRC Corp Ltd', '9'],
#    ['CSPC Pharmaceutical Group Ltd', '1'],
#    ['Dongyue Group Ltd', '3']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['East Money Information Co Ltd', '3'],
#    ['ENN Energy Holdings Ltd', '68'],
#    ['FinVolution Group', '5'],
#    ['Founder Securities Co Ltd', '1'],
#    ['Full Truck Alliance Co Ltd', '44'],
#    ['Fuyao Glass Industry Group Co Ltd', '22'],
#    ['GCL Technology Holdings Ltd', '1'],
#    ['GDS Holdings Ltd', '14'],
#    ['Geely Automobile Holdings Ltd', '9'],
#    ['GF Securities Co Ltd', '8'],
#    ['Giant Biogene Holding Co ltd', '3'],
#    ['Gree Electric Appliances Inc of Zhuhai', '30'],
#    ['Greentown Service Group Co Ltd', '1'],
#    ['Guoyuan Securities Co Ltd', '4'],
#    ['H World Group Ltd', '23'],
#    ['Haidilao International Holding Ltd', '7'],
#    ['Haier Smart Home Co Ltd', '128'],
#    ['Haitong Securities Co Ltd', '1'],
#    ['Hansoh Pharmaceutical Group Co Ltd', '6'],
#    ['Hisense Home Appliances Group Co Ltd', '4'],
#    ['Hisense Visual Technology Co Ltd', '3'],
#    ['HLA Group Corp Ltd', '9'],
#    ['Huatai Securities Co Ltd', '17'],
#    ['Huaxia Bank Co Ltd', '33'],
#    ['Hubei Dinglong Co Ltd', '2'],
#    ['Hygon Information Technology Co Ltd', '11'],
#    ['Industrial & Commercial Bank Of China, Luxembourg Branch', '156'],
#    ['Inner Mongolia Yili Industrial Group Co Ltd', '85']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Innovent Biologics Inc', '3'],
#    ['JD Health International Inc', '1'],
#    ['JD Logistics Inc', '2'],
#    ['JD.com Inc', '194'],
#    ['Jiangsu Hengrui Pharmaceuticals Co Ltd', '2'],
#    ['Jinduicheng Molybdenum Co Ltd', '5'],
#    ['JNBY Design Ltd', '1'],
#    ['Joincare Pharmaceutical Group Industry Co Ltd', '3'],
#    ['JOYY Inc', '3'],
#    ['Kanzhun Ltd', '3'],
#    ['KE Holdings Inc', '54'],
#    ['Kingdee International Software Group Co Ltd', '3'],
#    ['Kingnet Network Co Ltd', '9'],
#    ['Kingsoft Corp Ltd', '32'],
#    ['Kuaishou Technology', '100'],
#    ['Kweichow Moutai Co Ltd', '31'],
#    ['Lenovo Group Ltd', '59'],
#    ['Li Auto Inc', '71'],
#    ['Longfor Group Holdings Ltd', '31'],
#    ['Meituan', '431'],
#    ['Midea Group Co Ltd', '120'],
#    ['Minth Group Ltd', '18'],
#    ['MMG Ltd', '24'],
#    ['NARI Technology Co Ltd', '61'],
#    ['NetEase Cloud Music Inc', '1'],
#    ['NetEase Inc', '136'],
#    ['New China Life Insurance Co Ltd', '2'],
#    ['New Oriental Education & Technology Group Inc', '21']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Ningbo Ronbay New Energy Technology Co Ltd', '17'],
#    ['NIO Inc', '1'],
#    ['Nongfu Spring Co Ltd', '1'],
#    ['Orient Securities Co Ltd/China', '5'],
#    ['PDD Holdings Inc', '205'],
#    ['PICC Property & Casualty Co Ltd', '80'],
#    ['Ping An Insurance Group Co of China Ltd', '315'],
#    ['Pop Mart International Group Ltd', '19'],
#    ['Postal Savings Bank of China Co Ltd', '6'],
#    ['Qifu Technology Inc', '40'],
#    ['Sany Heavy Industry Co Ltd', '47'],
#    ['SF Holding Co Ltd', '22'],
#    ['SG Micro Corp', '18'],
#    ['Shandong Himile Mechanical Science & Technology Co Ltd', '7'],
#    ['Shandong Hi\xadspeed Co Ltd', '15'],
#    ['Shandong Nanshan Aluminum Co Ltd', '14'],
#    ['Shandong Weigao Group Medical Polymer Co Ltd', '6'],
#    ['Shanghai Chicmax Cosmetic Co Ltd', '2'],
#    ['Shanghai Pudong Development Bank Co Ltd', '28'],
#    ['Shanghai Rural Commercial Bank Co Ltd', '1'],
#    ['Shenzhen Inovance Technology Co Ltd', '29'],
#    ['Shenzhen Mindray Bio\xadMedical Electronics Co Ltd', '44'],
#    ['Shenzhen New Industries Biomedical Engineering Co Ltd', '25'],
#    ['Shenzhou International Group Holdings Ltd', '31'],
#    ['Sieyuan Electric Co Ltd', '21'],
#    ['Sino Biopharmaceutical Ltd', '10'],
#    ['Sinopharm Group Co Ltd', '1'],
#    ['Sunac Services Holdings Ltd', '1']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Sungrow Power Supply Co Ltd', '10'],
#    ['Sunny Optical Technology Group Co Ltd', '36'],
#    ['Sunwoda Electronic Co Ltd', '3'],
#    ['Tencent Holdings Ltd', '1.578'],
#    ['Tencent Music Entertainment Group', '29'],
#    ['Tingyi Cayman Islands Holding Corp', '21'],
#    ['Tongcheng Travel Holdings Ltd', '38'],
#    ['Tongwei Co Ltd', '25'],
#    ['Trip.com Group Ltd', '212'],
#    ['Tsingtao Brewery Co Ltd', '2'],
#    ['Universal Scientific Industrial Shanghai Co Ltd', '12'],
#    ['Vipshop Holdings Ltd', '34'],
#    ['Wanhua Chemical Group Co Ltd', '16'],
#    ['Want Want China Holdings Ltd', '1'],
#    ['Weichai Power Co Ltd', '44'],
#    ['Western Mining Co Ltd', '13'],
#    ['Will Semiconductor Co Ltd Shanghai', '9'],
#    ['Wuliangye Yibin Co Ltd', '43'],
#    ['WuXi AppTec Co Ltd', '1'],
#    ['Wuxi Biologics Cayman Inc', '9'],
#    ['Xiaomi Corp', '151'],
#    ['Xinyi Solar Holdings Ltd', '14'],
#    ['XPeng Inc', '4'],
#    ['Xtep International Holdings Ltd', '5'],
#    ['Yadea Group Holdings Ltd', '12'],
#    ['Yealink Network Technology Corp Ltd', '4'],
#    ['Yifeng Pharmacy Chain Co Ltd', '23'],
#    ['Yum China Holdings Inc', '13']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Yunnan Yuntianhua Co Ltd', '29'],
#    ['Yutong Bus Co Ltd', '26'],
#    ['Zhejiang Longsheng Group Co Ltd', '28'],
#    ['Zhejiang Semir Garment Co Ltd', '1'],
#    ['Zhejiang Supor Co Ltd', '30'],
#    ['Zhongsheng Group Holdings Ltd', '21'],
#    ['Zijin Mining Group Co Ltd', '61'],
#    ['ZTE Corp', '19'],
#    ['ZTO Express Cayman Inc', '38'],
#    ['Filippijnen', '454'],
#    ['Ayala Land Inc', '59'],
#    ['Bank of the Philippine Islands', '26'],
#    ['BDO Unibank Inc', '34'],
#    ['Bloomberry Resorts Corp', '5'],
#    ['DigiPlus Interactive Corp', '1'],
#    ['International Container Terminal Services Inc', '18'],
#    ['Metropolitan Bank & Trust Co', '8'],
#    ['SM Investments Corp', '7'],
#    ['SM Prime Holdings Inc', '297'],
#    ['Hong Kong', '1.906'],
#    ['AIA Group Ltd', '182'],
#    ['CLP Holdings Ltd', '35'],
#    ['ESR Group Ltd', '309'],
#    ['Futu Holdings Ltd', '15'],
#    ['Hang Lung Properties Ltd', '88'],
#    ['Hang Seng Bank Ltd', '19']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Henderson Land Development Co Ltd', '9'],
#    ['HKT Trust & HKT Ltd', '10'],
#    ['Hong Kong & China Gas Co Ltd', '18'],
#    ['Hong Kong Exchanges & Clearing Ltd', '99'],
#    ['Hongkong Land Holdings Ltd', '45'],
#    ['HSBC Holdings PLC', '480'],
#    ['Link REIT', '305'],
#    ['MTR Corp Ltd', '12'],
#    ['Sun Hung Kai Properties Ltd', '122'],
#    ['Swire Pacific Ltd', '8'],
#    ['Swire Properties Ltd', '18'],
#    ['Techtronic Industries Co Ltd', '43'],
#    ['Wharf Holdings Ltd/The', '3'],
#    ['Wharf Real Estate Investment Co Ltd', '88'],
#    ['', ''],
#    ['India', '4.456'],
#    ['ABB India Ltd', '51'],
#    ['Alkem Laboratories Ltd', '3'],
#    ['Ambuja Cements Ltd', '1'],
#    ['Anant Raj Ltd', '4'],
#    ['Apollo Hospitals Enterprise Ltd', '37'],
#    ['Ashok Leyland Ltd', '1'],
#    ['Ashoka Buildcon Ltd', '6'],
#    ['Asian Paints Ltd', '2'],
#    ['Astral Ltd', '1'],
#    ['Aurobindo Pharma Ltd', '4'],
#    ['Avenue Supermarts Ltd', '1'],
#    ['Axis Bank Ltd', '117']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Bajaj Auto Ltd', '23'],
#    ['Bajaj Finance Ltd', '47'],
#    ['Bajaj Finserv Ltd', '3'],
#    ['Bajaj Holdings & Investment Ltd', '1'],
#    ['Bajaj Housing Finance Ltd', '5'],
#    ['Balkrishna Industries Ltd', '1'],
#    ['Bank of Baroda', '24'],
#    ['Bharat Forge Ltd', '8'],
#    ['Bharti Airtel Ltd', '152'],
#    ['Bharti Hexacom Ltd', '25'],
#    ['Birlasoft Ltd', '2'],
#    ['Blue Star Ltd', '25'],
#    ['Britannia Industries Ltd', '8'],
#    ['Can Fin Homes Ltd', '1'],
#    ['Canara Bank', '11'],
#    ['Ceat Ltd', '5'],
#    ['CG Power & Industrial Solutions Ltd', '1'],
#    ['Chambal Fertilisers and Chemicals Ltd', '1'],
#    ['Cholamandalam Financial Holdings Ltd', '6'],
#    ['Cholamandalam Investment and Finance Co Ltd', '59'],
#    ['Cipla Ltd/India', '37'],
#    ['CMS Info Systems Ltd', '2'],
#    ['Coforge Ltd', '10'],
#    ['Colgate\xadPalmolive India Ltd', '28'],
#    ['Computer Age Management Services Ltd', '16'],
#    ['Craftsman Automation Ltd', '12'],
#    ['CRISIL Ltd', '3'],
#    ['Cummins India Ltd', '7']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Dabur India Ltd', '1'],
#    ['Delhivery Ltd', '12'],
#    ['Divi’s Laboratories Ltd', '1'],
#    ['Dixon Technologies India Ltd', '15'],
#    ['DLF Ltd', '83'],
#    ['Dr Reddy’s Laboratories Ltd', '6'],
#    ['Edelweiss Financial Services Ltd', '1'],
#    ['Eicher Motors Ltd', '64'],
#    ['EID Parry India Ltd', '1'],
#    ['Embassy Office Parks REIT', '22'],
#    ['Entero Healthcare Solutions Ltd', '15'],
#    ['EPL Ltd', '2'],
#    ['Escorts Kubota Ltd', '10'],
#    ['Finolex Cables Ltd', '1'],
#    ['Force Motors Ltd', '2'],
#    ['Fortis Healthcare Ltd', '10'],
#    ['GlaxoSmithKline Pharmaceuticals Ltd', '1'],
#    ['Glenmark Pharmaceuticals Ltd', '22'],
#    ['Global Health Ltd/India', '15'],
#    ['GMR Airports Ltd', '30'],
#    ['Godawari Power and Ispat Ltd', '7'],
#    ['Godrej Consumer Products Ltd', '1'],
#    ['Godrej Properties Ltd', '72'],
#    ['Grasim Industries Ltd', '1'],
#    ['Gujarat Pipavav Port Ltd', '10'],
#    ['Gujarat State Petronet Ltd', '1'],
#    ['Havells India Ltd', '27'],
#    ['HCL Technologies Ltd', '83']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['HDFC Asset Management Co Ltd', '14'],
#    ['HDFC Bank Ltd', '416'],
#    ['HDFC Life Insurance Co Ltd', '23'],
#    ['Hero MotoCorp Ltd', '8'],
#    ['Hindalco Industries Ltd', '25'],
#    ['Hindustan Aeronautics Ltd', '39'],
#    ['Hindustan Unilever Ltd', '25'],
#    ['Home First Finance Co India Ltd', '6'],
#    ['ICICI Bank Ltd', '301'],
#    ['ICICI Lombard General Insurance Co Ltd', '10'],
#    ['ICICI Prudential Life Insurance Co Ltd', '17'],
#    ['ICICI Securities Ltd', '1'],
#    ['IIFL Finance Ltd', '1'],
#    ['IndiaMart InterMesh Ltd', '6'],
#    ['Indian Energy Exchange Ltd', '4'],
#    ['Indian Hotels Co Ltd/The', '63'],
#    ['Indraprastha Gas Ltd', '3'],
#    ['Indus Towers Ltd', '5'],
#    ['Info Edge India Ltd', '27'],
#    ['Infosys Ltd', '264'],
#    ['InterGlobe Aviation Ltd', '22'],
#    ['Inventurus Knowledge Solutions Ltd', '4'],
#    ['ITD Cementation India Ltd', '2'],
#    ['Jamna Auto Industries Ltd', '2'],
#    ['JB Chemicals & Pharmaceuticals Ltd', '4'],
#    ['Jio Financial Services Ltd', '17'],
#    ['JSW Steel Ltd', '1'],
#    ['Jubilant Foodworks Ltd', '1']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Jyothy Labs Ltd', '1'],
#    ['Kalyan Jewellers India Ltd', '16'],
#    ['Karur Vysya Bank Ltd/The', '7'],
#    ['Kfin Technologies Ltd', '7'],
#    ['Kirloskar Brothers Ltd', '1'],
#    ['Kirloskar Oil Engines Ltd', '2'],
#    ['Kotak Mahindra Bank Ltd', '4'],
#    ['KPIT Technologies Ltd', '13'],
#    ['Lemon Tree Hotels Ltd', '198'],
#    ['LIC Housing Finance Ltd', '9'],
#    ['Lupin Ltd', '63'],
#    ['Macrotech Developers Ltd', '98'],
#    ['Mahanagar Gas Ltd', '20'],
#    ['Mahindra & Mahindra Ltd', '36'],
#    ['MakeMyTrip Ltd', '28'],
#    ['Manappuram Finance Ltd', '6'],
#    ['Mankind Pharma Ltd', '3'],
#    ['Marico Ltd', '1'],
#    ['Maruti Suzuki India Ltd', '4'],
#    ['Max Healthcare Institute Ltd', '49'],
#    ['Motilal Oswal Financial Services Ltd', '8'],
#    ['Mphasis Ltd', '10'],
#    ['MRF Ltd', '1'],
#    ['Multi Commodity Exchange of India Ltd', '9'],
#    ['Muthoot Finance Ltd', '3'],
#    ['NCC Ltd/India', '2'],
#    ['Nestle India Ltd', '1'],
#    ['NIIT Learning Systems Ltd', '1']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Nippon Life India Asset Management Ltd', '3'],
#    ['NTPC Ltd', '20'],
#    ['Nuvama Wealth Management Ltd', '2'],
#    ['Oberoi Realty Ltd', '22'],
#    ['Oracle Financial Services Software Ltd', '5'],
#    ['Page Industries Ltd', '11'],
#    ['Paradeep Phosphates Ltd', '4'],
#    ['Patanjali Foods Ltd', '17'],
#    ['PB Fintech Ltd', '21'],
#    ['Persistent Systems Ltd', '29'],
#    ['Phoenix Mills Ltd/The', '44'],
#    ['PI Industries Ltd', '27'],
#    ['Pidilite Industries Ltd', '12'],
#    ['Piramal Enterprises Ltd', '2'],
#    ['PNB Housing Finance Ltd', '9'],
#    ['Polycab India Ltd', '4'],
#    ['Power Grid Corp of India Ltd', '122'],
#    ['Prestige Estates Projects Ltd', '46'],
#    ['PTC India Ltd', '8'],
#    ['Punjab National Bank', '5'],
#    ['Rainbow Children’s Medicare Ltd', '17'],
#    ['Ramco Cements Ltd/The', '1'],
#    ['Ramkrishna Forgings Ltd', '2'],
#    ['REC Ltd', '49'],
#    ['Reliance Infrastructure Ltd', '1'],
#    ['Samvardhana Motherson International Ltd', '16'],
#    ['SBI Life Insurance Co Ltd', '38'],
#    ['Shree Cement Ltd', '1']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Shriram Finance Ltd', '41'],
#    ['SignatureGlobal India Ltd', '1'],
#    ['Sona Blw Precision Forgings Ltd', '15'],
#    ['SRF Ltd', '1'],
#    ['State Bank of India', '51'],
#    ['Sun Pharmaceutical Industries Ltd', '50'],
#    ['Supreme Industries Ltd', '4'],
#    ['Suzlon Energy Ltd', '1'],
#    ['Tata Consultancy Services Ltd', '179'],
#    ['Tata Elxsi Ltd', '1'],
#    ['Tata Motors Ltd', '23'],
#    ['Tata Power Co Ltd/The', '1'],
#    ['Tata Steel Ltd', '2'],
#    ['Tech Mahindra Ltd', '6'],
#    ['Titagarh Rail System Ltd', '6'],
#    ['Titan Co Ltd', '10'],
#    ['Torrent Pharmaceuticals Ltd', '49'],
#    ['Torrent Power Ltd', '1'],
#    ['Transport Corp of India Ltd', '1'],
#    ['Trent Ltd', '31'],
#    ['Triveni Turbine Ltd', '13'],
#    ['Tube Investments of India Ltd', '17'],
#    ['TVS Motor Co Ltd', '1'],
#    ['UltraTech Cement Ltd', '48'],
#    ['Union Bank of India Ltd', '5'],
#    ['United Spirits Ltd', '1'],
#    ['UPL Ltd', '30'],
#    ['Varun Beverages Ltd', '58']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Vodafone Idea Ltd', '10'],
#    ['Voltas Ltd', '1'],
#    ['Welspun Living Ltd', '1'],
#    ['Westlife Foodworld Ltd', '13'],
#    ['Wipro Ltd', '9'],
#    ['Zensar Technologies Ltd', '4'],
#    ['Zomato Ltd', '55'],
#    ['Indonesië', '508'],
#    ['Amman Mineral Internasional PT', '1'],
#    ['Aspirasi Hidup Indonesia Tbk PT', '1'],
#    ['Bank Central Asia Tbk PT', '139'],
#    ['Bank Mandiri Persero Tbk PT', '48'],
#    ['Bank Negara Indonesia Persero Tbk PT', '66'],
#    ['Bank Rakyat Indonesia Persero Tbk PT', '133'],
#    ['Chandra Asri Pacific Tbk PT', '1'],
#    ['Daya Intiguna Yasa Tbk PT', '13'],
#    ['GoTo Gojek Tokopedia Tbk PT', '1'],
#    ['Indosat Tbk PT', '20'],
#    ['Japfa Comfeed Indonesia Tbk PT', '2'],
#    ['Semen Indonesia Persero Tbk PT', '8'],
#    ['Sumber Alfaria Trijaya Tbk PT', '20'],
#    ['Telkom Indonesia Persero Tbk PT', '35'],
#    ['Vale Indonesia Tbk PT', '22'],
#    ['Israël', '72'],
#    ['Azrieli Group Ltd', '5'],
#    ['Check Point Software Technologies Ltd', '39']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Nova Ltd', '12'],
#    ['Phoenix Financial Ltd', '3'],
#    ['Tower Semiconductor Ltd', '12'],
#    ['Japan', '7.686'],
#    ['Advantest Corp', '71'],
#    ['Aeon Co Ltd', '45'],
#    ['Air Water Inc', '6'],
#    ['Aisin Corp', '16'],
#    ['Ajinomoto Co Inc', '47'],
#    ['Amada Co Ltd', '7'],
#    ['ANA Holdings Inc', '6'],
#    ['Asahi Intecc Co Ltd', '9'],
#    ['Asahi Kasei Corp', '21'],
#    ['Asics Corp', '35'],
#    ['Astellas Pharma Inc', '41'],
#    ['Azbil Corp', '9'],
#    ['Bridgestone Corp', '48'],
#    ['Brother Industries Ltd', '10'],
#    ['Central Japan Railway Co', '85'],
#    ['Chiba Bank Ltd/The', '12'],
#    ['Chugai Pharmaceutical Co Ltd', '68'],
#    ['Concordia Financial Group Ltd', '14'],
#    ['Dai Nippon Printing Co Ltd', '15'],
#    ['Daifuku Co Ltd', '44'],
#    ['Dai\xadichi Life Holdings Inc', '57'],
#    ['Daiichi Sankyo Co Ltd', '120']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Daito Trust Construction Co Ltd', '15'],
#    ['Daiwa House Industry Co Ltd', '47'],
#    ['Daiwa House REIT Investment Corp', '26'],
#    ['Daiwa Securities Group Inc', '20'],
#    ['Dentsu Group Inc', '12'],
#    ['Disco Corp', '420'],
#    ['East Japan Railway Co', '46'],
#    ['Ebara Corp', '16'],
#    ['Eisai Co Ltd', '18'],
#    ['FANUC Corp', '55'],
#    ['Fast Retailing Co Ltd', '192'],
#    ['Fuji Electric Co Ltd', '18'],
#    ['FUJIFILM Holdings Corp', '60'],
#    ['Fujikura Ltd', '25'],
#    ['Fujitsu Ltd', '74'],
#    ['Fukuoka Financial Group Inc', '10'],
#    ['GLP J\xadReit', '8'],
#    ['Hankyu Hanshin Holdings Inc', '14'],
#    ['Haseko Corp', '8'],
#    ['Hikari Tsushin Inc', '9'],
#    ['Hirose Electric Co Ltd', '8'],
#    ['Hoshizaki Corp', '10'],
#    ['Hoya Corp', '99'],
#    ['Hulic Co Ltd', '38'],
#    ['Ibiden Co Ltd', '10'],
#    ['IHI Corp', '20'],
#    ['Internet Initiative Japan Inc', '6'],
#    ['Invincible Investment Corp', '15']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Isetan Mitsukoshi Holdings Ltd', '15'],
#    ['Isuzu Motors Ltd', '20'],
#    ['Japan Airport Terminal Co Ltd', '6'],
#    ['Japan Exchange Group Inc', '27'],
#    ['Japan Hotel REIT Investment Corp', '12'],
#    ['Japan Metropolitan Fund Invest', '9'],
#    ['Japan Post Bank Co Ltd', '29'],
#    ['Japan Real Estate Investment Corp', '8'],
#    ['Kajima Corp', '19'],
#    ['Kansai Electric Power Co Inc/The', '22'],
#    ['Kansai Paint Co Ltd', '6'],
#    ['Kao Corp', '44'],
#    ['Kawasaki Kisen Kaisha Ltd', '14'],
#    ['KDX Realty Investment Corp', '35'],
#    ['Keio Corp', '6'],
#    ['Keisei Electric Railway Co Ltd', '10'],
#    ['Keyence Corp', '192'],
#    ['Kintetsu Group Holdings Co Ltd', '9'],
#    ['Kobe Bussan Co Ltd', '8'],
#    ['Koito Manufacturing Co Ltd', '7'],
#    ['Komatsu Ltd', '61'],
#    ['Konami Group Corp', '21'],
#    ['Kubota Corp', '32'],
#    ['Kuraray Co Ltd', '10'],
#    ['Kurita Water Industries Ltd', '9'],
#    ['Kyoto Financial Group Inc', '9'],
#    ['Kyowa Kirin Co Ltd', '8'],
#    ['Kyushu Railway Co', '8']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Lasertec Corp', '20'],
#    ['Lixil Corp', '7'],
#    ['LY Corp', '16'],
#    ['M3 Inc', '9'],
#    ['Makita Corp', '19'],
#    ['Marui Group Co Ltd', '7'],
#    ['MatsukiyoCocokara & Co', '13'],
#    ['Mazda Motor Corp', '9'],
#    ['McDonald’s Holdings Co Japan Ltd', '7'],
#    ['Mebuki Financial Group Inc', '9'],
#    ['Medipal Holdings Corp', '7'],
#    ['MINEBEA MITSUMI Inc', '14'],
#    ['MISUMI Group Inc', '10'],
#    ['Mitsubishi Chemical Group Corp', '16'],
#    ['Mitsubishi Electric Corp', '82'],
#    ['Mitsubishi Estate Co Ltd', '67'],
#    ['Mitsubishi HC Capital Inc', '16'],
#    ['Mitsubishi Heavy Industries Ltd', '107'],
#    ['Mitsubishi UFJ Financial Group Inc', '316'],
#    ['Mitsui Chemicals Inc', '9'],
#    ['Mitsui Fudosan Co Ltd', '66'],
#    ['Mitsui Fudosan Logistics Park Inc', '20'],
#    ['Mitsui OSK Lines Ltd', '28'],
#    ['Miura Co Ltd', '5'],
#    ['Mizuho Financial Group Inc', '140'],
#    ['MonotaRO Co Ltd', '9'],
#    ['MS&AD Insurance Group Holdings Inc', '72'],
#    ['Murata Manufacturing Co Ltd', '69']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Nexon Co Ltd', '11'],
#    ['NGK Insulators Ltd', '9'],
#    ['Nichirei Corp', '8'],
#    ['Nidec Corp', '44'],
#    ['Nikon Corp', '8'],
#    ['Nintendo Co Ltd', '154'],
#    ['Nippon Building Fund Inc', '11'],
#    ['Nippon Paint Holdings Co Ltd', '15'],
#    ['Nippon Prologis REIT Inc', '26'],
#    ['Nippon Telegraph & Telephone Corp', '67'],
#    ['Nippon Yusen KK', '36'],
#    ['Nissan Motor Co Ltd', '15'],
#    ['Nissin Foods Holdings Co Ltd', '13'],
#    ['Niterra Co Ltd', '14'],
#    ['Nitori Holdings Co Ltd', '25'],
#    ['Nomura Holdings Inc', '41'],
#    ['Nomura Real Estate Holdings Inc', '6'],
#    ['Nomura Real Estate Master Fund Inc', '6'],
#    ['Nomura Research Institute Ltd', '33'],
#    ['NTT Data Group Corp', '25'],
#    ['Obic Co Ltd', '23'],
#    ['Odakyu Electric Railway Co Ltd', '7'],
#    ['Olympus Corp', '41'],
#    ['Omron Corp', '15'],
#    ['Ono Pharmaceutical Co Ltd', '11'],
#    ['Open House Group Co Ltd', '6'],
#    ['Oracle Corp Japan', '7'],
#    ['Orix JREIT Inc', '15']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Osaka Gas Co Ltd', '20'],
#    ['Otsuka Corp', '13'],
#    ['Otsuka Holdings Co Ltd', '62'],
#    ['Pan Pacific International Holdings Corp', '24'],
#    ['Panasonic Holdings Corp', '57'],
#    ['Persol Holdings Co Ltd', '6'],
#    ['Recruit Holdings Co Ltd', '243'],
#    ['Renesas Electronics Corp', '56'],
#    ['Resona Holdings Inc', '40'],
#    ['Ricoh Co Ltd', '15'],
#    ['Rohm Co Ltd', '7'],
#    ['Rohto Pharmaceutical Co Ltd', '9'],
#    ['Sanrio Co Ltd', '16'],
#    ['Sanwa Holdings Corp', '13'],
#    ['Sapporo Holdings Ltd', '9'],
#    ['SCREEN Holdings Co Ltd', '14'],
#    ['SCSK Corp', '7'],
#    ['Secom Co Ltd', '33'],
#    ['Sega Sammy Holdings Inc', '7'],
#    ['Seibu Holdings Inc', '11'],
#    ['Seiko Epson Corp', '13'],
#    ['Sekisui Chemical Co Ltd', '16'],
#    ['Sekisui House Ltd', '37'],
#    ['Shimadzu Corp', '18'],
#    ['Shimano Inc', '51'],
#    ['Shimizu Corp', '11'],
#    ['Shin\xadEtsu Chemical Co Ltd', '152'],
#    ['Shionogi & Co Ltd', '29']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Shiseido Co Ltd', '16'],
#    ['Shizuoka Financial Group Inc', '10'],
#    ['Skylark Holdings Co Ltd', '8'],
#    ['SMC Corp', '54'],
#    ['Socionext Inc', '7'],
#    ['SoftBank Group Corp', '138'],
#    ['Sohgo Security Services Co Ltd', '6'],
#    ['Sompo Holdings Inc', '115'],
#    ['Sony Group Corp', '304'],
#    ['Square Enix Holdings Co Ltd', '8'],
#    ['SUMCO Corp', '6'],
#    ['Sumitomo Electric Industries Ltd', '33'],
#    ['Sumitomo Forestry Co Ltd', '15'],
#    ['Sumitomo Metal Mining Co Ltd', '14'],
#    ['Sumitomo Mitsui Financial Group Inc', '213'],
#    ['Sumitomo Mitsui Trust Group Inc', '40'],
#    ['Sumitomo Realty & Development Co Ltd', '35'],
#    ['Suntory Beverage & Food Ltd', '9'],
#    ['Sysmex Corp', '21'],
#    ['T&D Holdings Inc', '22'],
#    ['Taisei Corp', '17'],
#    ['Takeda Pharmaceutical Co Ltd', '95'],
#    ['TDK Corp', '43'],
#    ['Terumo Corp', '66'],
#    ['TIS Inc', '12'],
#    ['Tobu Railway Co Ltd', '7'],
#    ['Tohoku Electric Power Co Inc', '8'],
#    ['Tokio Marine Holdings Inc', '163']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Tokyo Electron Ltd', '120'],
#    ['Tokyo Ohka Kogyo Co Ltd', '6'],
#    ['Tokyo Tatemono Co Ltd', '27'],
#    ['Tokyu Corp', '15'],
#    ['Tokyu Fudosan Holdings Corp', '22'],
#    ['Toray Industries Inc', '23'],
#    ['Tosoh Corp', '9'],
#    ['TOTO Ltd', '9'],
#    ['Toyota Industries Corp', '38'],
#    ['Toyota Tsusho Corp', '28'],
#    ['USS Co Ltd', '9'],
#    ['West Japan Railway Co', '19'],
#    ['Yamaha Corp', '8'],
#    ['Yamaha Motor Co Ltd', '19'],
#    ['Yaskawa Electric Corp', '231'],
#    ['Yokogawa Electric Corp', '13'],
#    ['Yokohama Rubber Co Ltd/The', '8'],
#    ['ZOZO Inc', '9'],
#    ['', ''],
#    ['Kazachstan', '97'],
#    ['Kaspi.KZ JSC', '97'],
#    ['Koeweit', '67'],
#    ['Ali Alghanim Sons Automotive Co KSCC', '1'],
#    ['Boursa Kuwait Securities Co KPSC', '1'],
#    ['Gulf Bank KSCP', '1'],
#    ['Kuwait Finance House KSCP', '32']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Kuwait Telecommunications Co', '1'],
#    ['Mobile Telecommunications Co KSCP', '3'],
#    ['National Bank of Kuwait SAKP', '30'],
#    ['Maleisië', '229'],
#    ['AMMB Holdings Bhd', '9'],
#    ['Bursa Malaysia Bhd', '5'],
#    ['CIMB Group Holdings Bhd', '93'],
#    ['Frontken Corp Bhd', '19'],
#    ['Gamuda Bhd', '13'],
#    ['Hartalega Holdings Bhd', '8'],
#    ['Hong Leong Bank Bhd', '18'],
#    ['IHH Healthcare Bhd', '1'],
#    ['IOI Properties Group Bhd', '2'],
#    ['Malayan Banking Bhd', '5'],
#    ['MR DIY Group M Bhd', '9'],
#    ['My EG Services Bhd', '2'],
#    ['Petronas Chemicals Group Bhd', '1'],
#    ['Petronas Gas Bhd', '1'],
#    ['Public Bank Bhd', '4'],
#    ['RHB Bank Bhd', '2'],
#    ['Scientex BHD', '2'],
#    ['SP Setia Bhd Group', '3'],
#    ['Telekom Malaysia Bhd', '4'],
#    ['Tenaga Nasional Bhd', '12'],
#    ['Top Glove Corp Bhd', '8'],
#    ['YTL Power International Bhd', '11']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['', ''],
#    ['Qatar', '45'],
#    ['Commercial Bank Of Qatar Qsc/The', '1'],
#    ['Industries Qatar QSC', '3'],
#    ['Masraf Al Rayan QSC', '1'],
#    ['Qatar International Islamic Bank QSC', '1'],
#    ['Qatar Islamic Bank QPSC', '14'],
#    ['Qatar National Bank QPSC', '25'],
#    ['', ''],
#    ['Saoedi-Arabië', '726'],
#    ['ACWA Power Co', '10'],
#    ['Al Rajhi Bank', '187'],
#    ['Alinma Bank', '7'],
#    ['Almarai Co JSC', '8'],
#    ['Arab National Bank', '38'],
#    ['Arabian Internet & Communications Services Co', '4'],
#    ['Bank AlBilad', '1'],
#    ['Banque Saudi Fransi', '7'],
#    ['Bupa Arabia for Cooperative Insurance Co', '4'],
#    ['Co for Cooperative Insurance/The', '12'],
#    ['Dr Sulaiman Al Habib Medical Services Group Co', '24'],
#    ['Elm Co', '40'],
#    ['Etihad Etisalat Co', '80'],
#    ['Leejam Sports Co JSC', '7'],
#    ['Mouwasat Medical Services Co', '12'],
#    ['Riyad Bank', '37'],
#    ['Riyadh Cables Group Co', '15'],
#    ['Saudi Arabian Mining Co', '20']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Saudi Awwal Bank', '67'],
#    ['Saudi Basic Industries Corp', '17'],
#    ['Saudi Electricity Co', '3'],
#    ['Saudi Investment Bank/The', '1'],
#    ['Saudi National Bank/The', '55'],
#    ['Saudi Research & Media Group', '1'],
#    ['Saudi Tadawul Group Holding Co', '5'],
#    ['Saudi Telecom Co', '45'],
#    ['United Electronics Co', '15'],
#    ['Yanbu National Petrochemical Co', '3'],
#    ['', ''],
#    ['Singapore', '855'],
#    ['CapitaLand Ascendas REIT', '61'],
#    ['CapitaLand Ascott Trust', '8'],
#    ['CapitaLand Integrated Commercial Trust', '76'],
#    ['Capitaland Investment Ltd/Singapore', '49'],
#    ['DBS Group Holdings Ltd', '199'],
#    ['Digital Core REIT Management Pte Ltd', '8'],
#    ['Frasers Logistics & Commercial Trust', '15'],
#    ['Grab Holdings Ltd', '32'],
#    ['Keppel DC REIT', '29'],
#    ['Keppel Ltd', '16'],
#    ['Mapletree Industrial Trust', '7'],
#    ['Mapletree Logistics Trust', '34'],
#    ['Mapletree Pan Asia Commercial Trust', '20'],
#    ['Oversea\xadChinese Banking Corp Ltd', '106'],
#    ['Sembcorp Industries Ltd', '8'],
#    ['Singapore Exchange Ltd', '16']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Singapore Technologies Engineering Ltd', '11'],
#    ['Singapore Telecommunications Ltd', '41'],
#    ['United Overseas Bank Ltd', '93'],
#    ['Wilmar International Ltd', '13'],
#    ['Yangzijiang Shipbuilding Holdings Ltd', '13'],
#    ['Taiwan', '5.412'],
#    ['Accton Technology Corp', '94'],
#    ['Acer Inc', '1'],
#    ['Advancetek Enterprise Co Ltd', '3'],
#    ['Advantech Co Ltd', '1'],
#    ['Airoha Technology Corp', '3'],
#    ['Airtac International Group', '25'],
#    ['Alchip Technologies Ltd', '33'],
#    ['Andes Technology Corp', '12'],
#    ['Arcadyan Technology Corp', '6'],
#    ['ASE Technology Holding Co Ltd', '51'],
#    ['Asia Cement Corp', '14'],
#    ['Asia Vital Components Co Ltd', '14'],
#    ['ASMedia Technology Inc', '14'],
#    ['ASPEED Technology Inc', '12'],
#    ['Asustek Computer Inc', '15'],
#    ['Brighton-Best International Taiwan Inc', '1'],
#    ['Capital Securities Corp', '1'],
#    ['Catcher Technology Co Ltd', '1'],
#    ['Cathay Financial Holding Co Ltd', '14'],
#    ['Chailease Holding Co Ltd', '1']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Cheng Shin Rubber Industry Co Ltd', '3'],
#    ['Chicony Electronics Co Ltd', '6'],
#    ['Chicony Power Technology Co Ltd', '4'],
#    ['Chief Telecom Inc', '19'],
#    ['China Airlines Ltd', '31'],
#    ['China Steel Corp', '1'],
#    ['Chroma ATE Inc', '79'],
#    ['Chunghwa Telecom Co Ltd', '3'],
#    ['Compal Electronics Inc', '44'],
#    ['CTBC Financial Holding Co Ltd', '64'],
#    ['Darfon Electronics Corp', '1'],
#    ['Delta Electronics Inc', '88'],
#    ['Depo Auto Parts Ind Co Ltd', '2'],
#    ['E Ink Holdings Inc', '29'],
#    ['E.Sun Financial Holding Co Ltd', '9'],
#    ['Elan Microelectronics Corp', '8'],
#    ['Elite Material Co Ltd', '16'],
#    ['eMemory Technology Inc', '48'],
#    ['Eternal Materials Co Ltd', '2'],
#    ['Eva Airways Corp', '36'],
#    ['Evergreen Marine Corp Taiwan Ltd', '29'],
#    ['Everlight Electronics Co Ltd', '1'],
#    ['Far Eastern New Century Corp', '6'],
#    ['Far EasTone Telecommunications Co Ltd', '3'],
#    ['First Financial Holding Co Ltd', '1'],
#    ['Formosa Plastics Corp', '1'],
#    ['Foxconn Technology Co Ltd', '3'],
#    ['Foxsemicon Integrated Technology Inc', '3']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Fubon Financial Holding Co Ltd', '126'],
#    ['Getac Holdings Corp', '1'],
#    ['Gigabyte Technology Co Ltd', '1'],
#    ['Global Unichip Corp', '3'],
#    ['Goldsun Building Materials Co Ltd', '1'],
#    ['Gourmet Master Co Ltd', '1'],
#    ['Hon Hai Precision Industry Co Ltd', '236'],
#    ['Hotai Motor Co Ltd', '1'],
#    ['Hua Nan Financial Holdings Co Ltd', '1'],
#    ['Huang Hsiang Construction Corp', '1'],
#    ['Innolux Corp', '1'],
#    ['International Games System Co Ltd', '16'],
#    ['Inventec Corp', '1'],
#    ['ITE Technology Inc', '6'],
#    ['Jinan Acetate Chemical Co Ltd', '2'],
#    ['KGI Financial Holding Co Ltd', '9'],
#    ['Kindom Development Co Ltd', '4'],
#    ['King Slide Works Co Ltd', '1'],
#    ['King Yuan Electronics Co Ltd', '20'],
#    ['Kinpo Electronics', '1'],
#    ['L&K Engineering Co Ltd', '3'],
#    ['Largan Precision Co Ltd', '25'],
#    ['Lite-On Technology Corp', '1'],
#    ['Lotes Co Ltd', '9'],
#    ['Makalot Industrial Co Ltd', '10'],
#    ['MediaTek Inc', '405'],
#    ['Mega Financial Holding Co Ltd', '2'],
#    ['Merida Industry Co Ltd', '13']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Micro\xadStar International Co Ltd', '1'],
#    ['Nan Pao Resins Chemical Co Ltd', '2'],
#    ['Nan Ya Plastics Corp', '1'],
#    ['Nien Made Enterprise Co Ltd', '3'],
#    ['Novatek Microelectronics Corp', '11'],
#    ['Pegatron Corp', '11'],
#    ['PharmaEssentia Corp', '1'],
#    ['Pixart Imaging Inc', '4'],
#    ['Pou Chen Corp', '13'],
#    ['Powertech Technology Inc', '4'],
#    ['Poya International Co Ltd', '2'],
#    ['President Chain Store Corp', '51'],
#    ['Primax Electronics Ltd', '4'],
#    ['Quanta Computer Inc', '9'],
#    ['Radiant Opto\xadElectronics Corp', '4'],
#    ['Raydium Semiconductor Corp', '2'],
#    ['Realtek Semiconductor Corp', '38'],
#    ['Shanghai Commercial & Savings Bank Ltd/The', '1'],
#    ['Shin Kong Financial Holding Co Ltd', '1'],
#    ['Silergy Corp', '49'],
#    ['SinoPac Financial Holdings Co Ltd', '6'],
#    ['Sunonwealth Electric Machine Industry Co Ltd', '2'],
#    ['Sunplus Technology Co Ltd', '4'],
#    ['Synnex Technology International Corp', '1'],
#    ['Taishin Financial Holding Co Ltd', '2'],
#    ['Taiwan Business Bank', '1'],
#    ['Taiwan Cooperative Financial Holding Co Ltd', '1'],
#    ['Taiwan Mobile Co Ltd', '1']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Taiwan Semiconductor Manufacturing Co Ltd', '3.190'],
#    ['TCC Group Holdings Co Ltd', '1'],
#    ['Topco Scientific Co Ltd', '7'],
#    ['Tripod Technology Corp', '16'],
#    ['Tung Ho Steel Enterprise Corp', '2'],
#    ['Unimicron Technology Corp', '22'],
#    ['Uni\xadPresident Enterprises Corp', '63'],
#    ['United Integrated Services Co Ltd', '15'],
#    ['United Microelectronics Corp', '2'],
#    ['Vanguard International Semiconductor Corp', '1'],
#    ['Voltronic Power Technology Corp', '15'],
#    ['Wan Hai Lines Ltd', '2'],
#    ['Wistron Corp', '3'],
#    ['Wiwynn Corp', '41'],
#    ['Wowprime Corp', '3'],
#    ['WPG Holdings Ltd', '1'],
#    ['Yageo Corp', '14'],
#    ['Yang Ming Marine Transport Corp', '9'],
#    ['Yankey Engineering Co Ltd', '1'],
#    ['Yuanta Financial Holding Co Ltd', '22'],
#    ['Zhen Ding Technology Holding Ltd', '1'],
#    ['Thailand', '433'],
#    ['Advanced Info Service PCL', '1'],
#    ['Airports of Thailand PCL', '1'],
#    ['Amata Corp PCL', '4'],
#    ['Asia Aviation PCL', '1']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Bangkok Airways PCL', '3'],
#    ['Bangkok Bank PCL', '41'],
#    ['Bangkok Dusit Medical Services PCL', '42'],
#    ['Bumrungrad Hospital PCL', '8'],
#    ['Central Pattana PCL', '39'],
#    ['Charoen Pokphand Foods PCL', '22'],
#    ['CP ALL PCL', '35'],
#    ['CP AXTRA PCL', '1'],
#    ['Delta Electronics Thailand PCL', '6'],
#    ['Gulf Energy Development PCL', '1'],
#    ['Indorama Ventures PCL', '13'],
#    ['I-TAIL Corp PCL', '6'],
#    ['Kasikornbank PCL', '77'],
#    ['Krung Thai Bank PCL', '40'],
#    ['Minor International PCL', '1'],
#    ['Osotspa PCL', '2'],
#    ['SCB X PCL', '54'],
#    ['Siam Cement PCL/The', '1'],
#    ['SISB PCL', '14'],
#    ['Supalai PCL', '3'],
#    ['True Corp PCL', '16'],
#    ['Verenigde Arabische Emiraten', '542'],
#    ['Abu Dhabi Commercial Bank PJSC', '49'],
#    ['Abu Dhabi Islamic Bank PJSC', '26'],
#    ['Air Arabia PJSC', '1'],
#    ['Aldar Properties PJSC', '86']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Deyaar Development PJSC', '2'],
#    ['Dubai Islamic Bank PJSC', '12'],
#    ['Emaar Properties PJSC', '214'],
#    ['Emirates NBD PJSC', '69'],
#    ['Emirates Telecommunications Group Co PJSC', '8'],
#    ['First Abu Dhabi Bank PJSC', '18'],
#    ['Lulu Retail Holdings PLC', '3'],
#    ['Parkin Co PJSC', '12'],
#    ['Salik Co PJSC', '27'],
#    ['Talabat Holding PLC', '14'],
#    ['', ''],
#    ['Vietnam', '157'],
#    ['FPT Corp', '74'],
#    ['Hoa Phat Group JSC', '16'],
#    ['Masan Group Corp', '5'],
#    ['Military Commercial Joint Stock Bank', '4'],
#    ['Mobile World Investment Corp', '6'],
#    ['Vietnam Dairy Products JSC', '47'],
#    ['Vincom Retail JSC', '5'],
#    ['Zuid Korea', '2.740'],
#    ['Alteogen Inc', '15'],
#    ['Amorepacific Corp', '2'],
#    ['BNK Financial Group Inc', '10'],
#    ['Celltrion Inc', '18'],
#    ['Cheil Worldwide Inc', '8'],
#    ['CJ CheilJedang Corp', '4']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Cosmax Inc', '22'],
#    ['Coupang Inc', '20'],
#    ['DB Insurance Co Ltd', '59'],
#    ['DGB Financial Group Inc', '7'],
#    ['Eo Technics Co Ltd', '9'],
#    ['Hana Financial Group Inc', '108'],
#    ['Hankook Tire & Technology Co Ltd', '30'],
#    ['Hansol Chemical Co Ltd', '6'],
#    ['Hanwha Aerospace Co Ltd', '7'],
#    ['Hanwha Engine', '1'],
#    ['HD Hyundai Electric Co Ltd', '52'],
#    ['HD HYUNDAI MIPO', '9'],
#    ['HLB Inc', '1'],
#    ['HMM Co Ltd', '1'],
#    ['Hyundai Glovis Co Ltd', '22'],
#    ['Hyundai Marine & Fire Insurance Co Ltd', '7'],
#    ['Hyundai Mobis Co Ltd', '66'],
#    ['Hyundai Motor Co', '69'],
#    ['Hyundai Rotem Co Ltd', '12'],
#    ['Industrial Bank of Korea', '5'],
#    ['JYP Entertainment Corp', '2'],
#    ['Kakao Corp', '3'],
#    ['KB Financial Group Inc', '198'],
#    ['KCC Corp', '2'],
#    ['KEPCO Engineering & Construction Co Inc', '1'],
#    ['Kia Corp', '77'],
#    ['Koh Young Technology Inc', '9'],
#    ['Korea Aerospace Industries Ltd', '1']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Korea Investment Holdings Co Ltd', '3'],
#    ['Korea Zinc Co Ltd', '1'],
#    ['Krafton Inc', '28'],
#    ['KT Corp', '2'],
#    ['Kumho Petrochemical Co Ltd', '1'],
#    ['LG Chem Ltd', '7'],
#    ['LG Corp', '1'],
#    ['LG Electronics Inc', '22'],
#    ['LG Energy Solution Ltd', '10'],
#    ['LG H&H Co Ltd', '9'],
#    ['Mirae Asset Securities Co Ltd', '2'],
#    ['NAVER Corp', '91'],
#    ['NH Investment & Securities Co Ltd', '2'],
#    ['Orion Corp/Republic of Korea', '12'],
#    ['Park Systems Corp', '9'],
#    ['Peptron Inc', '3'],
#    ['POSCO Holdings Inc', '4'],
#    ['Samsung Biologics Co Ltd', '46'],
#    ['Samsung C&T Corp', '17'],
#    ['Samsung Electro\xadMechanics Co Ltd', '1'],
#    ['Samsung Electronics Co Ltd', '898'],
#    ['Samsung Fire & Marine Insurance Co Ltd', '79'],
#    ['Samsung Life Insurance Co Ltd', '29'],
#    ['Samsung SDI Co Ltd', '17'],
#    ['Samsung SDS Co Ltd', '1'],
#    ['Samsung Securities Co Ltd', '22'],
#    ['Sanil Electric Co Ltd', '10'],
#    ['Shinhan Financial Group Co Ltd', '94']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['SK Hynix Inc', '357'],
#    ['SK Inc', '3'],
#    ['SK Square Co Ltd', '18'],
#    ['SK Telecom Co Ltd', '44'],
#    ['SOOP Co Ltd', '2'],
#    ['WONIK IPS Co Ltd', '2'],
#    ['Woori Financial Group Inc', '34'],
#    ['Yuhan Corp', '1'],
#    ['', ''],
#    ['Europa', '26.459'],
#    ['België', '606'],
#    ['Aedifica SA', '110'],
#    ['Ageas SA/NV', '19'],
#    ['Anheuser-Busch InBev SA/NV', '109'],
#    ['Argenx SE', '83'],
#    ['Azelis Group NV', '3'],
#    ['Cofinimmo SA', '46'],
#    ['D’ieteren Group', '8'],
#    ['Elia Group SA/NV', '6'],
#    ['Groupe Bruxelles Lambert NV', '12'],
#    ['KBC Group NV', '42'],
#    ['Lotus Bakeries NV', '10'],
#    ['Montea NV', '45'],
#    ['Sofina SA', '8'],
#    ['UCB SA', '56'],
#    ['Warehouses De Pauw CVA', '41'],
#    ['Xior Student Housing NV', '9']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['', ''],
#    ['Denemarken', '1.534'],
#    ['AP Moller \xad Maersk A/S', '26'],
#    ['Carlsberg AS', '19'],
#    ['Coloplast A/S', '37'],
#    ['Demant A/S', '7'],
#    ['Genmab A/S', '32'],
#    ['Novo Nordisk A/S', '887'],
#    ['Novonesis (Novozymes) B', '304'],
#    ['Orsted AS', '18'],
#    ['Pandora A/S', '33'],
#    ['Tryg A/S', '15'],
#    ['Vestas Wind Systems A/S', '154'],
#    ['Duitsland', '4.446'],
#    ['adidas AG', '92'],
#    ['Allianz SE', '270'],
#    ['Aroundtown SA', '6'],
#    ['Bayerische Motoren Werke AG', '65'],
#    ['BioNTech SE', '25'],
#    ['Birkenstock Holding Plc', '7'],
#    ['Brenntag SE', '17'],
#    ['Commerzbank AG', '37'],
#    ['Continental AG', '16'],
#    ['Daimler Truck Holding AG', '48'],
#    ['Deutsche Boerse AG', '99'],
#    ['Deutsche Telekom AG', '242']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Dr Ing hc F Porsche AG', '15'],
#    ['E.ON SE', '55'],
#    ['Evonik Industries AG', '9'],
#    ['Fresenius Medical Care AG', '20'],
#    ['Fresenius SE & Co KGaA', '32'],
#    ['Hannover Rueck SE', '35'],
#    ['Heidelberg Materials AG', '39'],
#    ['Henkel AG & Co KGaA', '48'],
#    ['Infineon Technologies AG', '96'],
#    ['Knorr\xadBremse AG', '10'],
#    ['LEG Immobilien SE', '112'],
#    ['Mercedes\xadBenz Group AG', '93'],
#    ['Merck KGaA', '44'],
#    ['MTU Aero Engines AG', '42'],
#    ['Muenchener Rueckversicherungs\xadGesellschaft AG in Muenchen', '216'],
#    ['QIAGEN NV', '22'],
#    ['Rational AG', '255'],
#    ['Rheinmetall AG', '64'],
#    ['RWE AG', '45'],
#    ['SAP SE', '650'],
#    ['Sartorius AG', '12'],
#    ['Siemens AG', '404'],
#    ['Siemens Energy AG', '76'],
#    ['Siemens Healthineers AG', '32'],
#    ['Symrise AG', '286'],
#    ['Talanx AG', '11']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['', ''],
#    ['Finland', '310'],
#    ['Elisa Oyj', '14'],
#    ['Fortum OYJ', '13'],
#    ['Kesko Oyj', '11'],
#    ['Kojamo Oyj', '28'],
#    ['Kone Oyj', '45'],
#    ['Metso Oyj', '16'],
#    ['Nordea Bank Abp', '86'],
#    ['Orion Oyj', '10'],
#    ['Sampo Oyj', '47'],
#    ['Stora Enso Oyj', '12'],
#    ['Valmet Oyj', '8'],
#    ['Wartsila OYJ Abp', '19'],
#    ['', ''],
#    ['Frankrijk', '3.335'],
#    ['Altarea SCA', '129'],
#    ['Amundi SA', '9'],
#    ['AXA SA', '149'],
#    ['BioMerieux', '11'],
#    ['BNP Paribas SA', '148'],
#    ['Bollore SE', '9'],
#    ['Bouygues SA', '17'],
#    ['Bureau Veritas SA', '22'],
#    ['Capgemini SE', '64'],
#    ['Carrefour SA', '18'],
#    ['Cie de Saint\xadGobain SA', '133'],
#    ['Cie Generale des Etablissements Michelin SCA', '53']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Covivio SA/France', '45'],
#    ['Credit Agricole SA', '37'],
#    ['Danone SA', '99'],
#    ['Dassault Systemes SE', '54'],
#    ['Edenred SE', '20'],
#    ['Engie SA', '66'],
#    ['EssilorLuxottica SA', '229'],
#    ['Eurofins Scientific SE', '14'],
#    ['Gecina SA', '45'],
#    ['Getlink SE', '11'],
#    ['ICADE', '22'],
#    ['Ipsen SA', '9'],
#    ['JCDecaux SE', '123'],
#    ['Kering SA', '40'],
#    ['Klepierre SA', '221'],
#    ['Legrand SA', '58'],
#    ['L’Oreal SA', '259'],
#    ['Mercialys SA', '45'],
#    ['Orange SA', '44'],
#    ['Publicis Groupe SA', '57'],
#    ['Sanofi SA', '254'],
#    ['Sartorius Stedim Biotech', '12'],
#    ['Schneider Electric SE', '396'],
#    ['Societe Generale SA', '49'],
#    ['Sodexo SA', '15'],
#    ['STMicroelectronics NV', '38'],
#    ['Unibail-Rodamco-Westfield', '125'],
#    ['Veolia Environnement SA', '45']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Vinci SA', '137'],
#    ['Vivendi SE', '4'],
#    ['', ''],
#    ['Griekenland', '181'],
#    ['Alpha Services and Holdings SA', '30'],
#    ['Eurobank Ergasias Services and Holdings SA', '44'],
#    ['JUMBO SA', '4'],
#    ['Metlen Energy & Metals SA', '1'],
#    ['National Bank of Greece SA', '60'],
#    ['Piraeus Financial Holdings SA', '44'],
#    ['', ''],
#    ['Hongarije', '164'],
#    ['Magyar Telekom Telecommunications PLC', '1'],
#    ['OTP Bank Nyrt', '115'],
#    ['Richter Gedeon Nyrt', '49'],
#    ['Ierland', '69'],
#    ['AIB Group PLC', '20'],
#    ['Irish Residential Properties REIT Plc', '23'],
#    ['Kingspan Group PLC', '26'],
#    ['Italië', '964'],
#    ['Amplifon SpA', '7'],
#    ['Banca Mediolanum SpA', '5'],
#    ['Banco BPM SpA', '27'],
#    ['Davide Campari-Milano NV', '8'],
#    ['De’ Longhi SpA', '274'],
#    ['FinecoBank Banca Fineco SpA', '23']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Generali', '70'],
#    ['Infrastrutture Wireless Italiane SpA', '8'],
#    ['Intesa Sanpaolo SPA', '144'],
#    ['Mediobanca Banca di Credito Finanziario SpA', '16'],
#    ['Moncler SpA', '25'],
#    ['Nexi SpA', '7'],
#    ['Poste Italiane SpA', '14'],
#    ['Prysmian SpA', '80'],
#    ['Snam SpA', '20'],
#    ['Stellantis NV', '62'],
#    ['Terna - Rete Elettrica Nazionale', '26'],
#    ['UniCredit SpA', '147'],
#    ['', ''],
#    ['Nederland', '2.247'],
#    ['Adyen NV', '99'],
#    ['Aegon NV', '20'],
#    ['Akzo Nobel NV', '22'],
#    ['Arcadis NV', '270'],
#    ['ASM International NV', '115'],
#    ['ASML Holding NV', '894'],
#    ['Avantium N.V.', '7'],
#    ['Coca-Cola Europacific Partners PLC', '38'],
#    ['CTP NV', '14'],
#    ['DSM\xadFirmenich AG', '79'],
#    ['Eurocommercial Properties NV', '54'],
#    ['EXOR NV', '22'],
#    ['Heineken Holding NV', '15'],
#    ['Heineken NV', '46']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['ING Groep NV', '116'],
#    ['Koninklijke KPN NV', '34'],
#    ['Nebius Group NV', '24'],
#    ['NN Group NV', '25'],
#    ['Prosus NV', '132'],
#    ['Sligro Food Group NV', '43'],
#    ['Universal Music Group NV', '46'],
#    ['Wolters Kluwer NV', '133'],
#    ['', ''],
#    ['Noorwegen', '374'],
#    ['Bakkafrost P/F', '5'],
#    ['DNB Bank ASA', '40'],
#    ['Entra ASA', '18'],
#    ['Gjensidige Forsikring ASA', '7'],
#    ['Kongsberg Gruppen ASA', '22'],
#    ['Norsk Hydro ASA', '16'],
#    ['Orkla ASA', '14'],
#    ['Salmar ASA', '7'],
#    ['Schibsted ASA', '7'],
#    ['SpareBank 1 Sor-Norge ASA', '3'],
#    ['Storebrand ASA', '11'],
#    ['Telenor ASA', '16'],
#    ['Tomra Systems ASA', '198'],
#    ['Yara International ASA', '9'],
#    ['', ''],
#    ['Oostenrijk', '85'],
#    ['ANDRITZ AG', '8'],
#    ['BAWAG Group AG', '14']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Erste Group Bank AG', '45'],
#    ['Verbund AG', '10'],
#    ['Wienerberger AG', '7'],
#    ['Polen', '312'],
#    ['Alior Bank SA', '2'],
#    ['Allegro.eu SA', '31'],
#    ['Bank Polska Kasa Opieki SA', '52'],
#    ['CCC SA', '1'],
#    ['CD Projekt SA', '2'],
#    ['Dino Polska SA', '47'],
#    ['Grupa Kety SA', '2'],
#    ['KGHM Polska Miedz SA', '40'],
#    ['LPP SA', '11'],
#    ['Orange Polska SA', '3'],
#    ['Powszechna Kasa Oszczednosci Bank Polski SA', '44'],
#    ['Powszechny Zaklad Ubezpieczen SA', '57'],
#    ['Santander Bank Polska SA', '9'],
#    ['XTB SA', '2'],
#    ['Zabka Group SA', '10'],
#    ['Portugal', '39'],
#    ['EDP Renovaveis SA', '7'],
#    ['EDP SA', '21'],
#    ['Jeronimo Martins SGPS SA', '11'],
#    ['Roemenië', '3']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['', ''],
#    ['Spanje', '1.178'],
#    ['Aena SME SA', '34'],
#    ['Amadeus IT Group SA', '71'],
#    ['Banco Bilbao Vizcaya Argentaria SA', '126'],
#    ['Banco Santander SA', '160'],
#    ['CaixaBank SA', '43'],
#    ['Cellnex Telecom SA', '35'],
#    ['Endesa SA', '15'],
#    ['Ferrovial SE', '45'],
#    ['Iberdrola SA', '180'],
#    ['Industria de Diseno Textil SA', '128'],
#    ['International Consolidated Airlines Group SA', '20'],
#    ['Merlin Properties Socimi SA', '79'],
#    ['Naturgy Energy Group SA', '4'],
#    ['Redeia Corp SA', '15'],
#    ['Telefonica SA', '40'],
#    ['Viscofan SA', '183'],
#    ['', ''],
#    ['Tsjechië', '10'],
#    ['Komercni Banka AS', '9'],
#    ['Moneta Money Bank AS', '1'],
#    ['', ''],
#    ['Turkije', '269'],
#    ['Akbank TAS', '109'],
#    ['Aygaz AS', '4'],
#    ['BIM Birlesik Magazalar AS', '44'],
#    ['Ford Otomotiv Sanayi AS', '11']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Haci Omer Sabanci Holding AS', '18'],
#    ['Is Yatirim Menkul Degerler AS', '5'],
#    ['Mavi Giyim Sanayi Ve Ticaret AS', '12'],
#    ['Migros Ticaret AS', '4'],
#    ['Pegasus Hava Tasimaciligi AS', '6'],
#    ['Sok Marketler Ticaret AS', '4'],
#    ['Torunlar Gayrimenkul Yatirim Ortakligi AS', '2'],
#    ['Turk Hava Yollari AO', '21'],
#    ['Turkcell Iletisim Hizmetleri AS', '1'],
#    ['Turkiye Is Bankasi AS', '3'],
#    ['Turkiye Sigorta AS', '1'],
#    ['Yapi ve Kredi Bankasi AS', '24'],
#    ['', ''],
#    ['Verenigd Koninkrijk', '5.460'],
#    ['3i Group PLC', '99'],
#    ['Admiral Group PLC', '19'],
#    ['Anglo American PLC', '29'],
# ...
#    ['Dayforce Inc', '25'],
#    ['Deere & Co', '265'],
#    ['Dell Technologies Inc', '76'],
#    ['Delta Air Lines Inc', '22'],
#    ['DexCom Inc', '70'],
#    ['Digital Realty Trust Inc', '1.567'],
#    ['Discover Financial Services', '97'],
#    ['Dollar General Corp', '39'],
#    ['Dollar Tree Inc', '35'],
#    ['Dominion Energy Inc', '101'],
#    ['DoorDash Inc', '127'],
#    ['DR Horton Inc', '125'],
#    ['DTE Energy Co', '57'],
#    ['DuPont de Nemours Inc', '72'],
#    ['Dynatrace Inc', '38'],
#    ['Eastman Chemical Co', '23'],
#    ['Eaton Corp PLC', '351'],
#    ['eBay Inc', '70'],
#    ['Ecolab Inc', '198']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Edison International', '70'],
#    ['Edwards Lifesciences Corp', '175'],
#    ['Electronic Arts Inc', '80'],
#    ['Elevance Health Inc', '192'],
#    ['Eli Lilly & Co', '1.788'],
#    ['Emerson Electric Co', '251'],
#    ['Enphase Energy Inc', '43'],
#    ['Entergy Corp', '74'],
#    ['EPAM Systems Inc', '29'],
#    ['Equifax Inc', '70'],
#    ['Equinix Inc', '1.319'],
#    ['Equitable Holdings Inc', '82'],
#    ['Equity LifeStyle Properties Inc', '27'],
#    ['Equity Residential', '843'],
#    ['Erie Indemnity Co', '23'],
#    ['Essential Properties Realty Trust Inc', '27'],
#    ['Essential Utilities Inc', '20'],
#    ['Essex Property Trust Inc', '64'],
#    ['Estee Lauder Cos Inc/The', '40'],
#    ['Everest Group Ltd', '36'],
#    ['Eversource Energy', '44'],
#    ['Exact Sciences Corp', '23'],
#    ['Exelon Corp', '85'],
#    ['Extra Space Storage Inc', '426'],
#    ['F5 Inc', '32'],
#    ['FactSet Research Systems Inc', '42'],
#    ['Fair Isaac Corp', '108'],
#    ['Fastenal Co', '93']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Federal Realty Investment Trust', '39'],
#    ['Ferguson Enterprises Inc', '423'],
#    ['Fidelity National Financial Inc', '33'],
#    ['Fidelity National Information Services Inc', '100'],
#    ['Fifth Third Bancorp', '65'],
#    ['First Solar Inc', '42'],
#    ['Fiserv Inc', '317'],
#    ['Ford Motor Co', '87'],
#    ['Fortinet Inc', '134'],
#    ['Fortive Corp', '61'],
#    ['Fortune Brands Innovations Inc', '18'],
#    ['Fox Corp', '42'],
#    ['Franklin Resources Inc', '14'],
#    ['Garmin Ltd', '72'],
#    ['Gartner Inc', '83'],
#    ['GE HealthCare Technologies Inc', '74'],
#    ['Gen Digital Inc', '34'],
#    ['General Electric Co', '448'],
#    ['General Mills Inc', '81'],
#    ['Genuine Parts Co', '38'],
#    ['Gilead Sciences Inc', '261'],
#    ['Global Payments Inc', '64'],
#    ['Globe Life Inc', '21'],
#    ['GoDaddy Inc', '63'],
#    ['Goldman Sachs Group Inc/The', '481'],
#    ['Hartford Financial Services Group Inc/The', '72'],
#    ['HCA Healthcare Inc', '128'],
#    ['Healthcare Realty Trust Inc', '161']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Healthpeak Properties Inc', '80'],
#    ['HEICO Corp', '53'],
#    ['Hologic Inc', '39'],
#    ['Home Depot Inc/The', '1.066'],
#    ['Host Hotels & Resorts Inc', '63'],
#    ['Howmet Aerospace Inc', '100'],
#    ['Hubbell Inc', '50'],
#    ['HubSpot Inc', '79'],
#    ['Humana Inc', '69'],
#    ['Huntington Bancshares Inc/OH', '54'],
#    ['IDEX Corp', '88'],
#    ['Illinois Tool Works Inc', '170'],
#    ['Incyte Corp', '34'],
#    ['Independence Realty Trust Inc', '9'],
#    ['Ingersoll Rand Inc', '82'],
#    ['Insulet Corp', '42'],
#    ['Intel Corp', '194'],
#    ['Intercontinental Exchange Inc', '194'],
#    ['International Business Machines Corp', '466'],
#    ['International Flavors & Fragrances Inc', '116'],
#    ['Interpublic Group of Cos Inc/The', '23'],
#    ['Intuit Inc', '583'],
#    ['Intuitive Surgical Inc', '487'],
#    ['Invitation Homes Inc', '541'],
#    ['IQVIA Holdings Inc', '77'],
#    ['Iron Mountain Inc', '121'],
#    ['Jack Henry & Associates Inc', '351'],
#    ['JB Hunt Transport Services Inc', '31']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Johnson Controls International plc', '119'],
#    ['Jones Lang LaSalle Inc', '26'],
#    ['JPMorgan Chase & Co', '1.862'],
#    ['Juniper Networks Inc', '30'],
#    ['Keurig Dr Pepper Inc', '78'],
#    ['Keysight Technologies Inc', '63'],
#    ['Kilroy Realty Corp', '166'],
#    ['Kimberly\xadClark Corp', '98'],
#    ['Kimco Realty Corp', '307'],
#    ['KKR & Co Inc', '240'],
#    ['KLA Corp', '251'],
#    ['Kroger Co/The', '93'],
#    ['Labcorp Holdings Inc', '44'],
#    ['Lam Research Corp', '214'],
#    ['Lennox International Inc', '44'],
#    ['Lineage Inc', '7'],
#    ['LKQ Corp', '62'],
#    ['Loews Corp', '37'],
#    ['Lowe’s Cos Inc', '320'],
#    ['LPL Financial Holdings Inc', '55'],
#    ['Lululemon Athletica Inc', '151'],
#    ['LyondellBasell Industries NV', '45'],
#    ['M&T Bank Corp', '70'],
#    ['Macerich Co/The', '23'],
#    ['Maplebear Inc', '19'],
#    ['Markel Group Inc', '48'],
#    ['MarketAxess Holdings Inc', '18'],
#    ['Marsh & McLennan Cos Inc', '237']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Marvell Technology Inc', '279'],
#    ['Masco Corp', '37'],
#    ['Mastercard Inc', '1.337'],
#    ['McDonald’s Corp', '549'],
#    ['McKesson Corp', '167'],
#    ['Medical Properties Trust Inc', '5'],
#    ['Medtronic PLC', '235'],
#    ['MercadoLibre Inc', '239'],
#    ['Merck & Co Inc', '663'],
#    ['MetLife Inc', '108'],
#    ['Mettler-Toledo International Inc', '58'],
#    ['Microchip Technology Inc', '70'],
#    ['Micron Technology Inc', '211'],
#    ['Microsoft Corp', '7.004'],
#    ['Mid\xadAmerica Apartment Communities Inc', '445'],
#    ['Moderna Inc', '38'],
#    ['Molina Healthcare Inc', '39'],
#    ['Monolithic Power Systems Inc', '64'],
#    ['Monster Beverage Corp', '84'],
#    ['Moody’s Corp', '168'],
#    ['Morgan Stanley', '357'],
#    ['Mosaic Co/The', '17'],
#    ['MSA Safety Inc', '233'],
#    ['MSCI Inc', '105'],
#    ['Nasdaq Inc', '72'],
#    ['National Storage Affiliates Trust', '15'],
#    ['NetApp Inc', '54'],
#    ['NETSTREIT Corp', '16']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Neurocrine Biosciences Inc', '30'],
#    ['Newmont Corp', '96'],
#    ['NextEra Energy Inc', '529'],
#    ['NIKE Inc', '207'],
#    ['Norfolk Southern Corp', '120'],
#    ['Northern Trust Corp', '46'],
#    ['NVIDIA Corp', '7.297'],
#    ['NXP Semiconductors NV', '164'],
#    ['Okta Inc', '28'],
#    ['Omnicom Group Inc', '39'],
#    ['ON Semiconductor Corp', '61'],
#    ['Oracle Corp', '707'],
#    ['O’Reilly Automotive Inc', '154'],
#    ['Otis Worldwide Corp', '84'],
#    ['PACCAR Inc', '124'],
#    ['Palo Alto Networks Inc', '371'],
#    ['Parker-Hannifin Corp', '184'],
#    ['Paychex Inc', '102'],
#    ['Paycom Software Inc', '23'],
#    ['PayPal Holdings Inc', '197'],
#    ['Pentair PLC', '38'],
#    ['PepsiCo Inc', '548'],
#    ['Pfizer Inc', '397'],
#    ['Pinterest Inc', '40'],
#    ['PNC Financial Services Group Inc/The', '173'],
#    ['Pool Corp', '79'],
#    ['PPG Industries Inc', '64'],
#    ['Principal Financial Group Inc', '42']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Procter & Gamble Co/The', '1.045'],
#    ['Progressive Corp/The', '397'],
#    ['Prologis Inc', '2.166'],
#    ['Prudential Financial Inc', '95'],
#    ['PTC Inc', '50'],
#    ['Public Service Enterprise Group Inc', '95'],
#    ['Public Storage', '714'],
#    ['PulteGroup Inc', '50'],
#    ['Qorvo Inc', '15'],
#    ['QUALCOMM Inc', '392'],
#    ['Quest Diagnostics Inc', '38'],
#    ['Raymond James Financial Inc', '66'],
#    ['Realty Income Corp', '408'],
#    ['Regency Centers Corp', '169'],
#    ['Regeneron Pharmaceuticals Inc', '176'],
#    ['Regions Financial Corp', '48'],
#    ['Reinsurance Group of America Inc', '32'],
#    ['Republic Services Inc', '276'],
#    ['ResMed Inc', '75'],
#    ['Revvity Inc', '30'],
#    ['Rexford Industrial Realty Inc', '31'],
#    ['Rivian Automotive Inc', '21'],
#    ['Robinhood Markets Inc', '61'],
#    ['Rockwell Automation Inc', '73'],
#    ['Rollins Inc', '440'],
#    ['Roper Technologies Inc', '202'],
#    ['Ryman Hospitality Properties Inc', '20'],
#    ['S&P Global Inc', '412']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Sabra Health Care REIT Inc', '37'],
#    ['Salesforce Inc', '915'],
#    ['SBA Communications Corp', '48'],
#    ['Seagate Technology Holdings PLC', '41'],
#    ['SEI Investments Co', '21'],
#    ['Sempra', '126'],
#    ['SentinelOne Inc', '11'],
#    ['ServiceNow Inc', '578'],
#    ['Simon Property Group Inc', '211'],
#    ['Sirius XM Holdings Inc', '12'],
#    ['SITE Centers Corp', '12'],
#    ['Skyworks Solutions Inc', '33'],
#    ['Snap Inc', '29'],
#    ['Snap\xadon Inc', '41'],
#    ['Snowflake Inc', '116'],
#    ['Southwest Airlines Co', '12'],
#    ['Stanley Black & Decker Inc', '27'],
#    ['Starbucks Corp', '235'],
#    ['State Street Corp', '67'],
#    ['STERIS PLC', '294'],
#    ['Stryker Corp', '431'],
#    ['Sun Communities Inc', '82'],
#    ['Sunstone Hotel Investors Inc', '8'],
#    ['Super Micro Computer Inc', '35'],
#    ['Synchrony Financial', '57'],
#    ['Synopsys Inc', '293'],
#    ['Sysco Corp', '85'],
#    ['T Rowe Price Group Inc', '55']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Take-Two Interactive Software Inc', '68'],
#    ['Tanger Inc', '20'],
#    ['Target Corp', '142'],
#    ['TE Connectivity PLC', '97'],
#    ['Teledyne Technologies Inc', '47'],
#    ['Teleflex Inc', '18'],
#    ['Teradyne Inc', '91'],
#    ['Texas Instruments Inc', '451'],
#    ['The Bank of New York Mellon Corporation', '128'],
#    ['Thermo Fisher Scientific Inc', '616'],
#    ['TJX Cos Inc/The', '312'],
#    ['T-Mobile US Inc', '247'],
#    ['Tractor Supply Co', '64'],
#    ['Tradeweb Markets Inc', '33'],
#    ['Trane Technologies PLC', '189'],
#    ['TransDigm Group Inc', '161'],
#    ['TransUnion', '271'],
#    ['Travelers Cos Inc/The', '125'],
#    ['Trimble Inc', '40'],
#    ['Truist Financial Corp', '132'],
#    ['Twilio Inc', '39'],
#    ['Tyler Technologies Inc', '392'],
#    ['Uber Technologies Inc', '290'],
#    ['UDR Inc', '94'],
#    ['Ulta Beauty Inc', '48'],
#    ['UMH Properties Inc', '9'],
#    ['Union Pacific Corp', '318'],
#    ['United Airlines Holdings Inc', '18']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['United Rentals Inc', '105'],
#    ['UnitedHealth Group Inc', '1.357'],
#    ['Urban Edge Properties', '22'],
#    ['US Bancorp', '169'],
#    ['Veeva Systems Inc', '70'],
#    ['Ventas Inc', '699'],
#    ['Veralto Corp', '123'],
#    ['VeriSign Inc', '39'],
#    ['Verisk Analytics Inc', '87'],
#    ['Verizon Communications Inc', '445'],
#    ['Vertex Pharmaceuticals Inc', '317'],
#    ['Vertiv Holdings Co', '131'],
#    ['VICI Properties Inc', '100'],
#    ['Visa Inc', '1.408'],
#    ['Vistra Corp', '107'],
#    ['Vornado Realty Trust', '30'],
#    ['W R Berkley Corp', '40'],
#    ['Walmart Inc', '1.045'],
#    ['WALT DISNEY CO/THE', '536'],
#    ['Warner Bros Discovery Inc', '55'],
#    ['Waste Connections Inc', '99'],
#    ['Waste Management Inc', '256'],
#    ['Waters Corp', '50'],
#    ['WD\xad40 Co', '223'],
#    ['WEC Energy Group Inc', '67'],
#    ['Welltower Inc', '328'],
#    ['West Pharmaceutical Services Inc', '432'],
#    ['Western Digital Corp', '46']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Westinghouse Air Brake Technologies Corp', '75'],
#    ['Westlake Corp', '9'],
#    ['Willis Towers Watson PLC', '69'],
#    ['Workday Inc', '125'],
#    ['WP Carey Inc', '67'],
#    ['WW Grainger Inc', '104'],
#    ['Xylem Inc/NY', '64'],
#    ['Yum! Brands Inc', '85'],
#    ['Zebra Technologies Corp', '291'],
#    ['Zillow Group Inc', '34'],
#    ['Zimmer Biomet Holdings Inc', '47'],
#    ['Zoetis Inc', '242'],
#    ['Zoom Communications Inc', '50'],
#    ['Zscaler Inc', '40'],
#    ['', ''],
#    ['Oceanië', '4.089'],
#    ['Australië', '4.002'],
#    ['AGL Energy Ltd', '10'],
#    ['ALS Ltd', '10'],
#    ['ANZ Group Holdings Ltd', '121'],
#    ['APA Group', '13'],
#    ['Arena REIT', '8'],
#    ['Aristocrat Leisure Ltd', '59'],
#    ['ASX Ltd', '17'],
#    ['Atlas Arteria Ltd', '7'],
#    ['Bendigo & Adelaide Bank Ltd', '10'],
#    ['BlueScope Steel Ltd', '11']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['Brambles Ltd', '39'],
#    ['CAR Group Ltd', '19'],
#    ['Charter Hall Group', '29'],
#    ['Cleanaway Waste Management Ltd', '8'],
#    ['Cochlear Ltd', '277'],
#    ['Coles Group Ltd', '37'],
#    ['Commonwealth Bank of Australia', '382'],
#    ['Computershare Ltd', '29'],
#    ['CSL Ltd', '191'],
#    ['Dexus', '126'],
#    ['DigiCo Infrastructure REIT', '12'],
#    ['Fortescue Ltd', '43'],
#    ['Goodman Group', '1.095'],
#    ['GPT Group/The', '45'],
#    ['HMC Capital Ltd', '7'],
#    ['HomeCo Daily Needs REIT', '16'],
#    ['Incitec Pivot Ltd', '8'],
#    ['Ingenia Communities Group', '6'],
#    ['Insurance Australia Group Ltd', '29'],
#    ['JB Hi\xadFi Ltd', '14'],
#    ['Lynas Rare Earths Ltd', '8'],
#    ['Macquarie Group Ltd', '111'],
#    ['Mirvac Group', '283'],
#    ['National Australia Bank Ltd', '159'],
#    ['National Storage REIT', '16'],
#    ['NEXTDC Ltd', '41'],
#    ['Orica Ltd', '11'],
#    ['Pilbara Minerals Ltd', '8']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Pro Medicus Ltd', '19'],
#    ['QBE Insurance Group Ltd', '42'],
#    ['Qube Holdings Ltd', '9'],
#    ['Ramsay Health Care Ltd', '9'],
#    ['Reece Ltd', '11'],
#    ['Scentre Group', '104'],
#    ['SEEK Ltd', '11'],
#    ['SGH Ltd', '14'],
#    ['Sonic Healthcare Ltd', '18'],
#    ['Stockland', '65'],
#    ['Suncorp Group Ltd', '36'],
#    ['Telstra Group Ltd', '22'],
#    ['Transurban Group', '59'],
#    ['Treasury Wine Estates Ltd', '12'],
#    ['Vicinity Ltd', '25'],
#    ['Wesfarmers Ltd', '112'],
#    ['WiseTech Global Ltd', '33'],
#    ['Woolworths Group Ltd', '51'],
#    ['Xero Ltd', '36'],
#    ['Nieuw Zeeland', '87'],
#    ['Auckland International Airport Ltd', '14'],
#    ['Contact Energy Ltd', '9'],
#    ['EBOS Group Ltd', '7'],
#    ['Fisher & Paykel Healthcare Corp Ltd', '27'],
#    ['Infratil Ltd', '15'],
#    ['Meridian Energy Ltd', '9']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['', ''],
#    ['Zuid-Amerika', '1.539'],
#    ['Argentinië', '18'],
#    ['Grupo Financiero Galicia SA', '10'],
#    ['Telecom Argentina SA', '8'],
#    ['', ''],
#    ['Brazilië', '1.219'],
#    ['Allos SA', '8'],
#    ['Alupar Investimento SA', '4'],
#    ['Ambev SA', '76'],
#    ['B3 SA \xad Brasil Bolsa Balcao', '53'],
#    ['Banco Bradesco SA', '37'],
#    ['Banco BTG Pactual SA', '28'],
#    ['Banco do Brasil SA', '65'],
#    ['BB Seguridade Participacoes SA', '20'],
#    ['Bradespar SA', '1'],
#    ['BRF SA', '6'],
#    ['C&A MODAS SA', '1'],
#    ['CCR SA', '5'],
#    ['Centrais Eletricas Brasileiras SA', '17'],
#    ['Cia de Saneamento Basico do Estado de Sao Paulo SABESP', '36'],
#    ['Cia de Saneamento de Minas Gerais Copasa MG', '6'],
#    ['Cia De Sanena Do Parana', '6'],
#    ['Cia Energetica de Minas Gerais', '53'],
#    ['Cury Construtora e Incorporadora SA', '4'],
#    ['Cyrela Brazil Realty SA Empreendimentos e Participacoes', '19'],
#    ['Direcional Engenharia SA', '1']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Energisa S/A', '3'],
#    ['Equatorial Energia SA', '27'],
#    ['Fleury SA', '2'],
#    ['Gerdau SA', '6'],
#    ['Hapvida Participacoes e Investimentos S/A', '24'],
#    ['Itau Unibanco Holding SA', '107'],
#    ['Itausa SA', '31'],
#    ['JBS S/A', '8'],
#    ['Klabin SA', '12'],
#    ['Localiza Rent a Car SA', '6'],
#    ['Lojas Renner SA', '39'],
#    ['Marcopolo SA', '4'],
#    ['Multiplan Empreendimentos Imobiliarios SA', '3'],
#    ['Natura & Co Holding SA', '46'],
#    ['Neoenergia SA', '19'],
#    ['NU Holdings Ltd/Cayman Islands', '82'],
#    ['Porto Seguro SA', '15'],
#    ['Raia Drogasil SA', '55'],
#    ['Randon SA Implementos e Participacoes', '1'],
#    ['Rede D’Or Sao Luiz SA', '8'],
#    ['Rumo SA', '1'],
#    ['SLC Agricola SA', '4'],
#    ['Suzano SA', '3'],
#    ['Telefonica Brasil SA', '28'],
#    ['TIM SA/Brazil', '7'],
#    ['TOTVS SA', '18'],
#    ['Transmissora Alianca de Energia Eletrica S/A', '4'],
#    ['Vale SA', '109']]],
#  [[['Regio / Land / Uitgever', 'Waarde'],
#    ['WEG SA', '64'],
#    ['XP Inc', '34'],
#    ['YDUQS Participacoes SA', '2'],
#    ['Chili', '69'],
#    ['Banco de Chile', '24'],
#    ['Banco de Credito e Inversiones SA', '1'],
#    ['Banco Santander Chile', '8'],
#    ['Cencosud SA', '4'],
#    ['Embotelladora Andina SA', '7'],
#    ['Enel Americas SA', '3'],
#    ['Enel Chile SA', '6'],
#    ['Falabella SA', '2']],
#   [['Regio / Land / Uitgever', 'Waarde'],
#    ['Latam Airlines Group SA', '6'],
#    ['Sociedad Quimica y Minera de Chile SA', '10'],
#    ['', ''],
#    ['Colombia', '7'],
#    ['Bancolombia SA', '7'],
#    ['Peru', '226'],
#    ['Cia de Minas Buenaventura SAA', '3'],
#    ['Credicorp Ltd', '139'],
#    ['Southern Copper Corp', '85'],
#    ['Totaal', '181.555']]],
#  []]

# %%
tabs2 = sum(tabs, [])
tabs3 = sum(tabs2, [])
tabs3
# Out:
# [['Beursgenoteerde', ''],
#  ['beleggingen', None],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['', ''],
#  ['Afrika', '625'],
#  ['Zuid-Afrika', '625'],
#  ['Absa Group Ltd', '5'],
#  ['Anglo American Platinum Ltd', '1'],
#  ['Anglogold Ashanti Plc', '29'],
#  ['Aspen Pharmacare Holdings Ltd', '1'],
#  ['AVI Ltd', '7'],
#  ['Bid Corp Ltd', '8'],
#  ['Bidvest Group Ltd', '1'],
#  ['Capitec Bank Holdings Ltd', '55'],
#  ['Clicks Group Ltd', '25'],
#  ['Discovery Ltd', '5'],
#  ['FirstRand Ltd', '90'],
#  ['Foschini Group Ltd', '1'],
#  ['Gold Fields Ltd', '85'],
#  ['Hyprop Investments Ltd', '2'],
#  ['Impala Platinum Holdings Ltd', '32'],
#  ['Investec Ltd', '8'],
#  ['Life Healthcare Group Holdings Ltd', '1'],
#  ['Momentum Group Ltd', '2'],
#  ['Mr Price Group Ltd', '9'],
#  ['MTN Group Ltd', '17'],
#  ['Naspers Ltd', '117'],
#  ['Nedbank Group Ltd', '6'],
#  ['NEPI Rockcastle NV', '4'],
#  ['Old Mutual Ltd', '5'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Omnia Holdings Ltd', '1'],
#  ['OUTsurance Group Ltd', '16'],
#  ['Remgro Ltd', '1'],
#  ['Sanlam Ltd', '34'],
#  ['Sappi Ltd', '2'],
#  ['Shoprite Holdings Ltd', '33'],
#  ['Standard Bank Group Ltd', '22'],
#  ['Telkom SA SOC Ltd', '1'],
#  ['Vodacom Group Ltd', '1'],
#  ['Vukile Property Fund Ltd', '1'],
#  ['Woolworths Holdings Ltd/South Africa', '1'],
#  ['Azië', '34.689'],
#  ['China', '8.307'],
#  ['3SBio Inc', '6'],
#  ['AAC Technologies Holdings Inc', '19'],
#  ['Agricultural Bank of China Ltd', '60'],
#  ['Akeso Inc', '1'],
#  ['Alibaba Group Holding Ltd', '586'],
#  ['Anhui Conch Cement Co Ltd', '10'],
#  ['Anker Innovations Technology Co Ltd', '10'],
#  ['Atour Lifestyle Holdings Ltd', '17'],
#  ['Autohome Inc', '25'],
#  ['Baidu Inc', '54'],
#  ['Bank of China \xad Luxembourg Branch', '41'],
#  ['Bank of Communications Co Ltd', '2'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Bank of Ningbo Co Ltd', '3'],
#  ['BeiGene Ltd', '2'],
#  ['Beijing Jingneng Clean Energy Co Ltd', '1'],
#  ['Beijing Kingsoft Office Software Inc', '1'],
#  ['Beijing New Building Materials PLC', '5'],
#  ['Beijing Oriental Yuhong Waterproof Technology Co Ltd', '15'],
#  ['Bilibili Inc', '13'],
#  ['BOC Aviation Ltd', '2'],
#  ['BOE Technology Group Co Ltd', '31'],
#  ['Bosideng International Holdings Ltd', '31'],
#  ['Centre Testing International Group Co Ltd', '26'],
#  ['CGN Power Co Ltd', '1'],
#  ['China BlueChemical Ltd', '4'],
#  ['China CITIC Bank Corp Ltd', '6'],
#  ['China Communications Services Corp Ltd', '2'],
#  ['China Construction Bank Corp', '242'],
#  ['China CSSC Holdings Ltd', '2'],
#  ['China Everbright Bank Co Ltd', '6'],
#  ['China Feihe Ltd', '6'],
#  ['China Galaxy Securities Co Ltd', '8'],
#  ['China Hongqiao Group Ltd', '13'],
#  ['China International Capital Corp Ltd', '16'],
#  ['China International Marine Containers Group Co Ltd', '1'],
#  ['China Life Insurance Co Ltd', '9'],
#  ['China Medical System Holdings Ltd', '7'],
#  ['China Meidong Auto Holdings Ltd', '4'],
#  ['China Mengniu Dairy Co Ltd', '17'],
#  ['China Merchants Bank Co Ltd', '179'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['China Merchants Shekou Industrial Zone Holdings Co Ltd', '8'],
#  ['China Minsheng Banking Corp Ltd', '1'],
#  ['China Nonferrous Mining Corp Ltd', '2'],
#  ['China Overseas Land & Investment Ltd', '72'],
#  ['China Overseas Property Holdings Ltd', '1'],
#  ['China Pacific Insurance Group Co Ltd', '51'],
#  ['China Railway Group Ltd', '1'],
#  ['China Resources Beer Holdings Co Ltd', '52'],
#  ['China Resources Beverage Holdings Co Ltd', '10'],
#  ['China Resources Gas Group Ltd', '12'],
#  ['China Resources Land Ltd', '470'],
#  ['China Resources Mixc Lifestyle Services Ltd', '3'],
#  ['China South Publishing & Media Group Co Ltd', '8'],
#  ['China State Construction International Holdings Ltd', '1'],
#  ['China Taiping Insurance Holdings Co Ltd', '13'],
#  ['China Tower Corp Ltd', '8'],
#  ['China Yangtze Power Co Ltd', '31'],
#  ['Chongqing Rural Commercial Bank Co Ltd', '6'],
#  ['Chow Tai Fook Jewellery Group Ltd', '4'],
#  ['CITIC Securities Co Ltd', '3'],
#  ['CMOC Group Ltd', '20'],
#  ['Consun Pharmaceutical Group Ltd', '7'],
#  ['Contemporary Amperex Technology Co Ltd', '283'],
#  ['COSCO SHIPPING Holdings Co Ltd', '1'],
#  ['Country Garden Services Holdings Co Ltd', '4'],
#  ['CRRC Corp Ltd', '9'],
#  ['CSPC Pharmaceutical Group Ltd', '1'],
#  ['Dongyue Group Ltd', '3'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['East Money Information Co Ltd', '3'],
#  ['ENN Energy Holdings Ltd', '68'],
#  ['FinVolution Group', '5'],
#  ['Founder Securities Co Ltd', '1'],
#  ['Full Truck Alliance Co Ltd', '44'],
#  ['Fuyao Glass Industry Group Co Ltd', '22'],
#  ['GCL Technology Holdings Ltd', '1'],
#  ['GDS Holdings Ltd', '14'],
#  ['Geely Automobile Holdings Ltd', '9'],
#  ['GF Securities Co Ltd', '8'],
#  ['Giant Biogene Holding Co ltd', '3'],
#  ['Gree Electric Appliances Inc of Zhuhai', '30'],
#  ['Greentown Service Group Co Ltd', '1'],
#  ['Guoyuan Securities Co Ltd', '4'],
#  ['H World Group Ltd', '23'],
#  ['Haidilao International Holding Ltd', '7'],
#  ['Haier Smart Home Co Ltd', '128'],
#  ['Haitong Securities Co Ltd', '1'],
#  ['Hansoh Pharmaceutical Group Co Ltd', '6'],
#  ['Hisense Home Appliances Group Co Ltd', '4'],
#  ['Hisense Visual Technology Co Ltd', '3'],
#  ['HLA Group Corp Ltd', '9'],
#  ['Huatai Securities Co Ltd', '17'],
#  ['Huaxia Bank Co Ltd', '33'],
#  ['Hubei Dinglong Co Ltd', '2'],
#  ['Hygon Information Technology Co Ltd', '11'],
#  ['Industrial & Commercial Bank Of China, Luxembourg Branch', '156'],
#  ['Inner Mongolia Yili Industrial Group Co Ltd', '85'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Innovent Biologics Inc', '3'],
#  ['JD Health International Inc', '1'],
#  ['JD Logistics Inc', '2'],
#  ['JD.com Inc', '194'],
#  ['Jiangsu Hengrui Pharmaceuticals Co Ltd', '2'],
#  ['Jinduicheng Molybdenum Co Ltd', '5'],
#  ['JNBY Design Ltd', '1'],
#  ['Joincare Pharmaceutical Group Industry Co Ltd', '3'],
#  ['JOYY Inc', '3'],
#  ['Kanzhun Ltd', '3'],
#  ['KE Holdings Inc', '54'],
#  ['Kingdee International Software Group Co Ltd', '3'],
#  ['Kingnet Network Co Ltd', '9'],
#  ['Kingsoft Corp Ltd', '32'],
#  ['Kuaishou Technology', '100'],
#  ['Kweichow Moutai Co Ltd', '31'],
#  ['Lenovo Group Ltd', '59'],
#  ['Li Auto Inc', '71'],
#  ['Longfor Group Holdings Ltd', '31'],
#  ['Meituan', '431'],
#  ['Midea Group Co Ltd', '120'],
#  ['Minth Group Ltd', '18'],
#  ['MMG Ltd', '24'],
#  ['NARI Technology Co Ltd', '61'],
#  ['NetEase Cloud Music Inc', '1'],
#  ['NetEase Inc', '136'],
#  ['New China Life Insurance Co Ltd', '2'],
#  ['New Oriental Education & Technology Group Inc', '21'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Ningbo Ronbay New Energy Technology Co Ltd', '17'],
#  ['NIO Inc', '1'],
#  ['Nongfu Spring Co Ltd', '1'],
#  ['Orient Securities Co Ltd/China', '5'],
#  ['PDD Holdings Inc', '205'],
#  ['PICC Property & Casualty Co Ltd', '80'],
#  ['Ping An Insurance Group Co of China Ltd', '315'],
#  ['Pop Mart International Group Ltd', '19'],
#  ['Postal Savings Bank of China Co Ltd', '6'],
#  ['Qifu Technology Inc', '40'],
#  ['Sany Heavy Industry Co Ltd', '47'],
#  ['SF Holding Co Ltd', '22'],
#  ['SG Micro Corp', '18'],
#  ['Shandong Himile Mechanical Science & Technology Co Ltd', '7'],
#  ['Shandong Hi\xadspeed Co Ltd', '15'],
#  ['Shandong Nanshan Aluminum Co Ltd', '14'],
#  ['Shandong Weigao Group Medical Polymer Co Ltd', '6'],
#  ['Shanghai Chicmax Cosmetic Co Ltd', '2'],
#  ['Shanghai Pudong Development Bank Co Ltd', '28'],
#  ['Shanghai Rural Commercial Bank Co Ltd', '1'],
#  ['Shenzhen Inovance Technology Co Ltd', '29'],
#  ['Shenzhen Mindray Bio\xadMedical Electronics Co Ltd', '44'],
#  ['Shenzhen New Industries Biomedical Engineering Co Ltd', '25'],
#  ['Shenzhou International Group Holdings Ltd', '31'],
#  ['Sieyuan Electric Co Ltd', '21'],
#  ['Sino Biopharmaceutical Ltd', '10'],
#  ['Sinopharm Group Co Ltd', '1'],
#  ['Sunac Services Holdings Ltd', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Sungrow Power Supply Co Ltd', '10'],
#  ['Sunny Optical Technology Group Co Ltd', '36'],
#  ['Sunwoda Electronic Co Ltd', '3'],
#  ['Tencent Holdings Ltd', '1.578'],
#  ['Tencent Music Entertainment Group', '29'],
#  ['Tingyi Cayman Islands Holding Corp', '21'],
#  ['Tongcheng Travel Holdings Ltd', '38'],
#  ['Tongwei Co Ltd', '25'],
#  ['Trip.com Group Ltd', '212'],
#  ['Tsingtao Brewery Co Ltd', '2'],
#  ['Universal Scientific Industrial Shanghai Co Ltd', '12'],
#  ['Vipshop Holdings Ltd', '34'],
#  ['Wanhua Chemical Group Co Ltd', '16'],
#  ['Want Want China Holdings Ltd', '1'],
#  ['Weichai Power Co Ltd', '44'],
#  ['Western Mining Co Ltd', '13'],
#  ['Will Semiconductor Co Ltd Shanghai', '9'],
#  ['Wuliangye Yibin Co Ltd', '43'],
#  ['WuXi AppTec Co Ltd', '1'],
#  ['Wuxi Biologics Cayman Inc', '9'],
#  ['Xiaomi Corp', '151'],
#  ['Xinyi Solar Holdings Ltd', '14'],
#  ['XPeng Inc', '4'],
#  ['Xtep International Holdings Ltd', '5'],
#  ['Yadea Group Holdings Ltd', '12'],
#  ['Yealink Network Technology Corp Ltd', '4'],
#  ['Yifeng Pharmacy Chain Co Ltd', '23'],
#  ['Yum China Holdings Inc', '13'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Yunnan Yuntianhua Co Ltd', '29'],
#  ['Yutong Bus Co Ltd', '26'],
#  ['Zhejiang Longsheng Group Co Ltd', '28'],
#  ['Zhejiang Semir Garment Co Ltd', '1'],
#  ['Zhejiang Supor Co Ltd', '30'],
#  ['Zhongsheng Group Holdings Ltd', '21'],
#  ['Zijin Mining Group Co Ltd', '61'],
#  ['ZTE Corp', '19'],
#  ['ZTO Express Cayman Inc', '38'],
#  ['Filippijnen', '454'],
#  ['Ayala Land Inc', '59'],
#  ['Bank of the Philippine Islands', '26'],
#  ['BDO Unibank Inc', '34'],
#  ['Bloomberry Resorts Corp', '5'],
#  ['DigiPlus Interactive Corp', '1'],
#  ['International Container Terminal Services Inc', '18'],
#  ['Metropolitan Bank & Trust Co', '8'],
#  ['SM Investments Corp', '7'],
#  ['SM Prime Holdings Inc', '297'],
#  ['Hong Kong', '1.906'],
#  ['AIA Group Ltd', '182'],
#  ['CLP Holdings Ltd', '35'],
#  ['ESR Group Ltd', '309'],
#  ['Futu Holdings Ltd', '15'],
#  ['Hang Lung Properties Ltd', '88'],
#  ['Hang Seng Bank Ltd', '19'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Henderson Land Development Co Ltd', '9'],
#  ['HKT Trust & HKT Ltd', '10'],
#  ['Hong Kong & China Gas Co Ltd', '18'],
#  ['Hong Kong Exchanges & Clearing Ltd', '99'],
#  ['Hongkong Land Holdings Ltd', '45'],
#  ['HSBC Holdings PLC', '480'],
#  ['Link REIT', '305'],
#  ['MTR Corp Ltd', '12'],
#  ['Sun Hung Kai Properties Ltd', '122'],
#  ['Swire Pacific Ltd', '8'],
#  ['Swire Properties Ltd', '18'],
#  ['Techtronic Industries Co Ltd', '43'],
#  ['Wharf Holdings Ltd/The', '3'],
#  ['Wharf Real Estate Investment Co Ltd', '88'],
#  ['', ''],
#  ['India', '4.456'],
#  ['ABB India Ltd', '51'],
#  ['Alkem Laboratories Ltd', '3'],
#  ['Ambuja Cements Ltd', '1'],
#  ['Anant Raj Ltd', '4'],
#  ['Apollo Hospitals Enterprise Ltd', '37'],
#  ['Ashok Leyland Ltd', '1'],
#  ['Ashoka Buildcon Ltd', '6'],
#  ['Asian Paints Ltd', '2'],
#  ['Astral Ltd', '1'],
#  ['Aurobindo Pharma Ltd', '4'],
#  ['Avenue Supermarts Ltd', '1'],
#  ['Axis Bank Ltd', '117'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Bajaj Auto Ltd', '23'],
#  ['Bajaj Finance Ltd', '47'],
#  ['Bajaj Finserv Ltd', '3'],
#  ['Bajaj Holdings & Investment Ltd', '1'],
#  ['Bajaj Housing Finance Ltd', '5'],
#  ['Balkrishna Industries Ltd', '1'],
#  ['Bank of Baroda', '24'],
#  ['Bharat Forge Ltd', '8'],
#  ['Bharti Airtel Ltd', '152'],
#  ['Bharti Hexacom Ltd', '25'],
#  ['Birlasoft Ltd', '2'],
#  ['Blue Star Ltd', '25'],
#  ['Britannia Industries Ltd', '8'],
#  ['Can Fin Homes Ltd', '1'],
#  ['Canara Bank', '11'],
#  ['Ceat Ltd', '5'],
#  ['CG Power & Industrial Solutions Ltd', '1'],
#  ['Chambal Fertilisers and Chemicals Ltd', '1'],
#  ['Cholamandalam Financial Holdings Ltd', '6'],
#  ['Cholamandalam Investment and Finance Co Ltd', '59'],
#  ['Cipla Ltd/India', '37'],
#  ['CMS Info Systems Ltd', '2'],
#  ['Coforge Ltd', '10'],
#  ['Colgate\xadPalmolive India Ltd', '28'],
#  ['Computer Age Management Services Ltd', '16'],
#  ['Craftsman Automation Ltd', '12'],
#  ['CRISIL Ltd', '3'],
#  ['Cummins India Ltd', '7'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Dabur India Ltd', '1'],
#  ['Delhivery Ltd', '12'],
#  ['Divi’s Laboratories Ltd', '1'],
#  ['Dixon Technologies India Ltd', '15'],
#  ['DLF Ltd', '83'],
#  ['Dr Reddy’s Laboratories Ltd', '6'],
#  ['Edelweiss Financial Services Ltd', '1'],
#  ['Eicher Motors Ltd', '64'],
#  ['EID Parry India Ltd', '1'],
#  ['Embassy Office Parks REIT', '22'],
#  ['Entero Healthcare Solutions Ltd', '15'],
#  ['EPL Ltd', '2'],
#  ['Escorts Kubota Ltd', '10'],
#  ['Finolex Cables Ltd', '1'],
#  ['Force Motors Ltd', '2'],
#  ['Fortis Healthcare Ltd', '10'],
#  ['GlaxoSmithKline Pharmaceuticals Ltd', '1'],
#  ['Glenmark Pharmaceuticals Ltd', '22'],
#  ['Global Health Ltd/India', '15'],
#  ['GMR Airports Ltd', '30'],
#  ['Godawari Power and Ispat Ltd', '7'],
#  ['Godrej Consumer Products Ltd', '1'],
#  ['Godrej Properties Ltd', '72'],
#  ['Grasim Industries Ltd', '1'],
#  ['Gujarat Pipavav Port Ltd', '10'],
#  ['Gujarat State Petronet Ltd', '1'],
#  ['Havells India Ltd', '27'],
#  ['HCL Technologies Ltd', '83'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['HDFC Asset Management Co Ltd', '14'],
#  ['HDFC Bank Ltd', '416'],
#  ['HDFC Life Insurance Co Ltd', '23'],
#  ['Hero MotoCorp Ltd', '8'],
#  ['Hindalco Industries Ltd', '25'],
#  ['Hindustan Aeronautics Ltd', '39'],
#  ['Hindustan Unilever Ltd', '25'],
#  ['Home First Finance Co India Ltd', '6'],
#  ['ICICI Bank Ltd', '301'],
#  ['ICICI Lombard General Insurance Co Ltd', '10'],
#  ['ICICI Prudential Life Insurance Co Ltd', '17'],
#  ['ICICI Securities Ltd', '1'],
#  ['IIFL Finance Ltd', '1'],
#  ['IndiaMart InterMesh Ltd', '6'],
#  ['Indian Energy Exchange Ltd', '4'],
#  ['Indian Hotels Co Ltd/The', '63'],
#  ['Indraprastha Gas Ltd', '3'],
#  ['Indus Towers Ltd', '5'],
#  ['Info Edge India Ltd', '27'],
#  ['Infosys Ltd', '264'],
#  ['InterGlobe Aviation Ltd', '22'],
#  ['Inventurus Knowledge Solutions Ltd', '4'],
#  ['ITD Cementation India Ltd', '2'],
#  ['Jamna Auto Industries Ltd', '2'],
#  ['JB Chemicals & Pharmaceuticals Ltd', '4'],
#  ['Jio Financial Services Ltd', '17'],
#  ['JSW Steel Ltd', '1'],
#  ['Jubilant Foodworks Ltd', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Jyothy Labs Ltd', '1'],
#  ['Kalyan Jewellers India Ltd', '16'],
#  ['Karur Vysya Bank Ltd/The', '7'],
#  ['Kfin Technologies Ltd', '7'],
#  ['Kirloskar Brothers Ltd', '1'],
#  ['Kirloskar Oil Engines Ltd', '2'],
#  ['Kotak Mahindra Bank Ltd', '4'],
#  ['KPIT Technologies Ltd', '13'],
#  ['Lemon Tree Hotels Ltd', '198'],
#  ['LIC Housing Finance Ltd', '9'],
#  ['Lupin Ltd', '63'],
#  ['Macrotech Developers Ltd', '98'],
#  ['Mahanagar Gas Ltd', '20'],
#  ['Mahindra & Mahindra Ltd', '36'],
#  ['MakeMyTrip Ltd', '28'],
#  ['Manappuram Finance Ltd', '6'],
#  ['Mankind Pharma Ltd', '3'],
#  ['Marico Ltd', '1'],
#  ['Maruti Suzuki India Ltd', '4'],
#  ['Max Healthcare Institute Ltd', '49'],
#  ['Motilal Oswal Financial Services Ltd', '8'],
#  ['Mphasis Ltd', '10'],
#  ['MRF Ltd', '1'],
#  ['Multi Commodity Exchange of India Ltd', '9'],
#  ['Muthoot Finance Ltd', '3'],
#  ['NCC Ltd/India', '2'],
#  ['Nestle India Ltd', '1'],
#  ['NIIT Learning Systems Ltd', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Nippon Life India Asset Management Ltd', '3'],
#  ['NTPC Ltd', '20'],
#  ['Nuvama Wealth Management Ltd', '2'],
#  ['Oberoi Realty Ltd', '22'],
#  ['Oracle Financial Services Software Ltd', '5'],
#  ['Page Industries Ltd', '11'],
#  ['Paradeep Phosphates Ltd', '4'],
#  ['Patanjali Foods Ltd', '17'],
#  ['PB Fintech Ltd', '21'],
#  ['Persistent Systems Ltd', '29'],
#  ['Phoenix Mills Ltd/The', '44'],
#  ['PI Industries Ltd', '27'],
#  ['Pidilite Industries Ltd', '12'],
#  ['Piramal Enterprises Ltd', '2'],
#  ['PNB Housing Finance Ltd', '9'],
#  ['Polycab India Ltd', '4'],
#  ['Power Grid Corp of India Ltd', '122'],
#  ['Prestige Estates Projects Ltd', '46'],
#  ['PTC India Ltd', '8'],
#  ['Punjab National Bank', '5'],
#  ['Rainbow Children’s Medicare Ltd', '17'],
#  ['Ramco Cements Ltd/The', '1'],
#  ['Ramkrishna Forgings Ltd', '2'],
#  ['REC Ltd', '49'],
#  ['Reliance Infrastructure Ltd', '1'],
#  ['Samvardhana Motherson International Ltd', '16'],
#  ['SBI Life Insurance Co Ltd', '38'],
#  ['Shree Cement Ltd', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Shriram Finance Ltd', '41'],
#  ['SignatureGlobal India Ltd', '1'],
#  ['Sona Blw Precision Forgings Ltd', '15'],
#  ['SRF Ltd', '1'],
#  ['State Bank of India', '51'],
#  ['Sun Pharmaceutical Industries Ltd', '50'],
#  ['Supreme Industries Ltd', '4'],
#  ['Suzlon Energy Ltd', '1'],
#  ['Tata Consultancy Services Ltd', '179'],
#  ['Tata Elxsi Ltd', '1'],
#  ['Tata Motors Ltd', '23'],
#  ['Tata Power Co Ltd/The', '1'],
#  ['Tata Steel Ltd', '2'],
#  ['Tech Mahindra Ltd', '6'],
#  ['Titagarh Rail System Ltd', '6'],
#  ['Titan Co Ltd', '10'],
#  ['Torrent Pharmaceuticals Ltd', '49'],
#  ['Torrent Power Ltd', '1'],
#  ['Transport Corp of India Ltd', '1'],
#  ['Trent Ltd', '31'],
#  ['Triveni Turbine Ltd', '13'],
#  ['Tube Investments of India Ltd', '17'],
#  ['TVS Motor Co Ltd', '1'],
#  ['UltraTech Cement Ltd', '48'],
#  ['Union Bank of India Ltd', '5'],
#  ['United Spirits Ltd', '1'],
#  ['UPL Ltd', '30'],
#  ['Varun Beverages Ltd', '58'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Vodafone Idea Ltd', '10'],
#  ['Voltas Ltd', '1'],
#  ['Welspun Living Ltd', '1'],
#  ['Westlife Foodworld Ltd', '13'],
#  ['Wipro Ltd', '9'],
#  ['Zensar Technologies Ltd', '4'],
#  ['Zomato Ltd', '55'],
#  ['Indonesië', '508'],
#  ['Amman Mineral Internasional PT', '1'],
#  ['Aspirasi Hidup Indonesia Tbk PT', '1'],
#  ['Bank Central Asia Tbk PT', '139'],
#  ['Bank Mandiri Persero Tbk PT', '48'],
#  ['Bank Negara Indonesia Persero Tbk PT', '66'],
#  ['Bank Rakyat Indonesia Persero Tbk PT', '133'],
#  ['Chandra Asri Pacific Tbk PT', '1'],
#  ['Daya Intiguna Yasa Tbk PT', '13'],
#  ['GoTo Gojek Tokopedia Tbk PT', '1'],
#  ['Indosat Tbk PT', '20'],
#  ['Japfa Comfeed Indonesia Tbk PT', '2'],
#  ['Semen Indonesia Persero Tbk PT', '8'],
#  ['Sumber Alfaria Trijaya Tbk PT', '20'],
#  ['Telkom Indonesia Persero Tbk PT', '35'],
#  ['Vale Indonesia Tbk PT', '22'],
#  ['Israël', '72'],
#  ['Azrieli Group Ltd', '5'],
#  ['Check Point Software Technologies Ltd', '39'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Nova Ltd', '12'],
#  ['Phoenix Financial Ltd', '3'],
#  ['Tower Semiconductor Ltd', '12'],
#  ['Japan', '7.686'],
#  ['Advantest Corp', '71'],
#  ['Aeon Co Ltd', '45'],
#  ['Air Water Inc', '6'],
#  ['Aisin Corp', '16'],
#  ['Ajinomoto Co Inc', '47'],
#  ['Amada Co Ltd', '7'],
#  ['ANA Holdings Inc', '6'],
#  ['Asahi Intecc Co Ltd', '9'],
#  ['Asahi Kasei Corp', '21'],
#  ['Asics Corp', '35'],
#  ['Astellas Pharma Inc', '41'],
#  ['Azbil Corp', '9'],
#  ['Bridgestone Corp', '48'],
#  ['Brother Industries Ltd', '10'],
#  ['Central Japan Railway Co', '85'],
#  ['Chiba Bank Ltd/The', '12'],
#  ['Chugai Pharmaceutical Co Ltd', '68'],
#  ['Concordia Financial Group Ltd', '14'],
#  ['Dai Nippon Printing Co Ltd', '15'],
#  ['Daifuku Co Ltd', '44'],
#  ['Dai\xadichi Life Holdings Inc', '57'],
#  ['Daiichi Sankyo Co Ltd', '120'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Daito Trust Construction Co Ltd', '15'],
#  ['Daiwa House Industry Co Ltd', '47'],
#  ['Daiwa House REIT Investment Corp', '26'],
#  ['Daiwa Securities Group Inc', '20'],
#  ['Dentsu Group Inc', '12'],
#  ['Disco Corp', '420'],
#  ['East Japan Railway Co', '46'],
#  ['Ebara Corp', '16'],
#  ['Eisai Co Ltd', '18'],
#  ['FANUC Corp', '55'],
#  ['Fast Retailing Co Ltd', '192'],
#  ['Fuji Electric Co Ltd', '18'],
#  ['FUJIFILM Holdings Corp', '60'],
#  ['Fujikura Ltd', '25'],
#  ['Fujitsu Ltd', '74'],
#  ['Fukuoka Financial Group Inc', '10'],
#  ['GLP J\xadReit', '8'],
#  ['Hankyu Hanshin Holdings Inc', '14'],
#  ['Haseko Corp', '8'],
#  ['Hikari Tsushin Inc', '9'],
#  ['Hirose Electric Co Ltd', '8'],
#  ['Hoshizaki Corp', '10'],
#  ['Hoya Corp', '99'],
#  ['Hulic Co Ltd', '38'],
#  ['Ibiden Co Ltd', '10'],
#  ['IHI Corp', '20'],
#  ['Internet Initiative Japan Inc', '6'],
#  ['Invincible Investment Corp', '15'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Isetan Mitsukoshi Holdings Ltd', '15'],
#  ['Isuzu Motors Ltd', '20'],
#  ['Japan Airport Terminal Co Ltd', '6'],
#  ['Japan Exchange Group Inc', '27'],
#  ['Japan Hotel REIT Investment Corp', '12'],
#  ['Japan Metropolitan Fund Invest', '9'],
#  ['Japan Post Bank Co Ltd', '29'],
#  ['Japan Real Estate Investment Corp', '8'],
#  ['Kajima Corp', '19'],
#  ['Kansai Electric Power Co Inc/The', '22'],
#  ['Kansai Paint Co Ltd', '6'],
#  ['Kao Corp', '44'],
#  ['Kawasaki Kisen Kaisha Ltd', '14'],
#  ['KDX Realty Investment Corp', '35'],
#  ['Keio Corp', '6'],
#  ['Keisei Electric Railway Co Ltd', '10'],
#  ['Keyence Corp', '192'],
#  ['Kintetsu Group Holdings Co Ltd', '9'],
#  ['Kobe Bussan Co Ltd', '8'],
#  ['Koito Manufacturing Co Ltd', '7'],
#  ['Komatsu Ltd', '61'],
#  ['Konami Group Corp', '21'],
#  ['Kubota Corp', '32'],
#  ['Kuraray Co Ltd', '10'],
#  ['Kurita Water Industries Ltd', '9'],
#  ['Kyoto Financial Group Inc', '9'],
#  ['Kyowa Kirin Co Ltd', '8'],
#  ['Kyushu Railway Co', '8'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Lasertec Corp', '20'],
#  ['Lixil Corp', '7'],
#  ['LY Corp', '16'],
#  ['M3 Inc', '9'],
#  ['Makita Corp', '19'],
#  ['Marui Group Co Ltd', '7'],
#  ['MatsukiyoCocokara & Co', '13'],
#  ['Mazda Motor Corp', '9'],
#  ['McDonald’s Holdings Co Japan Ltd', '7'],
#  ['Mebuki Financial Group Inc', '9'],
#  ['Medipal Holdings Corp', '7'],
#  ['MINEBEA MITSUMI Inc', '14'],
#  ['MISUMI Group Inc', '10'],
#  ['Mitsubishi Chemical Group Corp', '16'],
#  ['Mitsubishi Electric Corp', '82'],
#  ['Mitsubishi Estate Co Ltd', '67'],
#  ['Mitsubishi HC Capital Inc', '16'],
#  ['Mitsubishi Heavy Industries Ltd', '107'],
#  ['Mitsubishi UFJ Financial Group Inc', '316'],
#  ['Mitsui Chemicals Inc', '9'],
#  ['Mitsui Fudosan Co Ltd', '66'],
#  ['Mitsui Fudosan Logistics Park Inc', '20'],
#  ['Mitsui OSK Lines Ltd', '28'],
#  ['Miura Co Ltd', '5'],
#  ['Mizuho Financial Group Inc', '140'],
#  ['MonotaRO Co Ltd', '9'],
#  ['MS&AD Insurance Group Holdings Inc', '72'],
#  ['Murata Manufacturing Co Ltd', '69'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Nexon Co Ltd', '11'],
#  ['NGK Insulators Ltd', '9'],
#  ['Nichirei Corp', '8'],
#  ['Nidec Corp', '44'],
#  ['Nikon Corp', '8'],
#  ['Nintendo Co Ltd', '154'],
#  ['Nippon Building Fund Inc', '11'],
#  ['Nippon Paint Holdings Co Ltd', '15'],
#  ['Nippon Prologis REIT Inc', '26'],
#  ['Nippon Telegraph & Telephone Corp', '67'],
#  ['Nippon Yusen KK', '36'],
#  ['Nissan Motor Co Ltd', '15'],
#  ['Nissin Foods Holdings Co Ltd', '13'],
#  ['Niterra Co Ltd', '14'],
#  ['Nitori Holdings Co Ltd', '25'],
#  ['Nomura Holdings Inc', '41'],
#  ['Nomura Real Estate Holdings Inc', '6'],
#  ['Nomura Real Estate Master Fund Inc', '6'],
#  ['Nomura Research Institute Ltd', '33'],
#  ['NTT Data Group Corp', '25'],
#  ['Obic Co Ltd', '23'],
#  ['Odakyu Electric Railway Co Ltd', '7'],
#  ['Olympus Corp', '41'],
#  ['Omron Corp', '15'],
#  ['Ono Pharmaceutical Co Ltd', '11'],
#  ['Open House Group Co Ltd', '6'],
#  ['Oracle Corp Japan', '7'],
#  ['Orix JREIT Inc', '15'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Osaka Gas Co Ltd', '20'],
#  ['Otsuka Corp', '13'],
#  ['Otsuka Holdings Co Ltd', '62'],
#  ['Pan Pacific International Holdings Corp', '24'],
#  ['Panasonic Holdings Corp', '57'],
#  ['Persol Holdings Co Ltd', '6'],
#  ['Recruit Holdings Co Ltd', '243'],
#  ['Renesas Electronics Corp', '56'],
#  ['Resona Holdings Inc', '40'],
#  ['Ricoh Co Ltd', '15'],
#  ['Rohm Co Ltd', '7'],
#  ['Rohto Pharmaceutical Co Ltd', '9'],
#  ['Sanrio Co Ltd', '16'],
#  ['Sanwa Holdings Corp', '13'],
#  ['Sapporo Holdings Ltd', '9'],
#  ['SCREEN Holdings Co Ltd', '14'],
#  ['SCSK Corp', '7'],
#  ['Secom Co Ltd', '33'],
#  ['Sega Sammy Holdings Inc', '7'],
#  ['Seibu Holdings Inc', '11'],
#  ['Seiko Epson Corp', '13'],
#  ['Sekisui Chemical Co Ltd', '16'],
#  ['Sekisui House Ltd', '37'],
#  ['Shimadzu Corp', '18'],
#  ['Shimano Inc', '51'],
#  ['Shimizu Corp', '11'],
#  ['Shin\xadEtsu Chemical Co Ltd', '152'],
#  ['Shionogi & Co Ltd', '29'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Shiseido Co Ltd', '16'],
#  ['Shizuoka Financial Group Inc', '10'],
#  ['Skylark Holdings Co Ltd', '8'],
#  ['SMC Corp', '54'],
#  ['Socionext Inc', '7'],
#  ['SoftBank Group Corp', '138'],
#  ['Sohgo Security Services Co Ltd', '6'],
#  ['Sompo Holdings Inc', '115'],
#  ['Sony Group Corp', '304'],
#  ['Square Enix Holdings Co Ltd', '8'],
#  ['SUMCO Corp', '6'],
#  ['Sumitomo Electric Industries Ltd', '33'],
#  ['Sumitomo Forestry Co Ltd', '15'],
#  ['Sumitomo Metal Mining Co Ltd', '14'],
#  ['Sumitomo Mitsui Financial Group Inc', '213'],
#  ['Sumitomo Mitsui Trust Group Inc', '40'],
#  ['Sumitomo Realty & Development Co Ltd', '35'],
#  ['Suntory Beverage & Food Ltd', '9'],
#  ['Sysmex Corp', '21'],
#  ['T&D Holdings Inc', '22'],
#  ['Taisei Corp', '17'],
#  ['Takeda Pharmaceutical Co Ltd', '95'],
#  ['TDK Corp', '43'],
#  ['Terumo Corp', '66'],
#  ['TIS Inc', '12'],
#  ['Tobu Railway Co Ltd', '7'],
#  ['Tohoku Electric Power Co Inc', '8'],
#  ['Tokio Marine Holdings Inc', '163'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Tokyo Electron Ltd', '120'],
#  ['Tokyo Ohka Kogyo Co Ltd', '6'],
#  ['Tokyo Tatemono Co Ltd', '27'],
#  ['Tokyu Corp', '15'],
#  ['Tokyu Fudosan Holdings Corp', '22'],
#  ['Toray Industries Inc', '23'],
#  ['Tosoh Corp', '9'],
#  ['TOTO Ltd', '9'],
#  ['Toyota Industries Corp', '38'],
#  ['Toyota Tsusho Corp', '28'],
#  ['USS Co Ltd', '9'],
#  ['West Japan Railway Co', '19'],
#  ['Yamaha Corp', '8'],
#  ['Yamaha Motor Co Ltd', '19'],
#  ['Yaskawa Electric Corp', '231'],
#  ['Yokogawa Electric Corp', '13'],
#  ['Yokohama Rubber Co Ltd/The', '8'],
#  ['ZOZO Inc', '9'],
#  ['', ''],
#  ['Kazachstan', '97'],
#  ['Kaspi.KZ JSC', '97'],
#  ['Koeweit', '67'],
#  ['Ali Alghanim Sons Automotive Co KSCC', '1'],
#  ['Boursa Kuwait Securities Co KPSC', '1'],
#  ['Gulf Bank KSCP', '1'],
#  ['Kuwait Finance House KSCP', '32'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Kuwait Telecommunications Co', '1'],
#  ['Mobile Telecommunications Co KSCP', '3'],
#  ['National Bank of Kuwait SAKP', '30'],
#  ['Maleisië', '229'],
#  ['AMMB Holdings Bhd', '9'],
#  ['Bursa Malaysia Bhd', '5'],
#  ['CIMB Group Holdings Bhd', '93'],
#  ['Frontken Corp Bhd', '19'],
#  ['Gamuda Bhd', '13'],
#  ['Hartalega Holdings Bhd', '8'],
#  ['Hong Leong Bank Bhd', '18'],
#  ['IHH Healthcare Bhd', '1'],
#  ['IOI Properties Group Bhd', '2'],
#  ['Malayan Banking Bhd', '5'],
#  ['MR DIY Group M Bhd', '9'],
#  ['My EG Services Bhd', '2'],
#  ['Petronas Chemicals Group Bhd', '1'],
#  ['Petronas Gas Bhd', '1'],
#  ['Public Bank Bhd', '4'],
#  ['RHB Bank Bhd', '2'],
#  ['Scientex BHD', '2'],
#  ['SP Setia Bhd Group', '3'],
#  ['Telekom Malaysia Bhd', '4'],
#  ['Tenaga Nasional Bhd', '12'],
#  ['Top Glove Corp Bhd', '8'],
#  ['YTL Power International Bhd', '11'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['', ''],
#  ['Qatar', '45'],
#  ['Commercial Bank Of Qatar Qsc/The', '1'],
#  ['Industries Qatar QSC', '3'],
#  ['Masraf Al Rayan QSC', '1'],
#  ['Qatar International Islamic Bank QSC', '1'],
#  ['Qatar Islamic Bank QPSC', '14'],
#  ['Qatar National Bank QPSC', '25'],
#  ['', ''],
#  ['Saoedi-Arabië', '726'],
#  ['ACWA Power Co', '10'],
#  ['Al Rajhi Bank', '187'],
#  ['Alinma Bank', '7'],
#  ['Almarai Co JSC', '8'],
#  ['Arab National Bank', '38'],
#  ['Arabian Internet & Communications Services Co', '4'],
#  ['Bank AlBilad', '1'],
#  ['Banque Saudi Fransi', '7'],
#  ['Bupa Arabia for Cooperative Insurance Co', '4'],
#  ['Co for Cooperative Insurance/The', '12'],
#  ['Dr Sulaiman Al Habib Medical Services Group Co', '24'],
#  ['Elm Co', '40'],
#  ['Etihad Etisalat Co', '80'],
#  ['Leejam Sports Co JSC', '7'],
#  ['Mouwasat Medical Services Co', '12'],
#  ['Riyad Bank', '37'],
#  ['Riyadh Cables Group Co', '15'],
#  ['Saudi Arabian Mining Co', '20'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Saudi Awwal Bank', '67'],
#  ['Saudi Basic Industries Corp', '17'],
#  ['Saudi Electricity Co', '3'],
#  ['Saudi Investment Bank/The', '1'],
#  ['Saudi National Bank/The', '55'],
#  ['Saudi Research & Media Group', '1'],
#  ['Saudi Tadawul Group Holding Co', '5'],
#  ['Saudi Telecom Co', '45'],
#  ['United Electronics Co', '15'],
#  ['Yanbu National Petrochemical Co', '3'],
#  ['', ''],
#  ['Singapore', '855'],
#  ['CapitaLand Ascendas REIT', '61'],
#  ['CapitaLand Ascott Trust', '8'],
#  ['CapitaLand Integrated Commercial Trust', '76'],
#  ['Capitaland Investment Ltd/Singapore', '49'],
#  ['DBS Group Holdings Ltd', '199'],
#  ['Digital Core REIT Management Pte Ltd', '8'],
#  ['Frasers Logistics & Commercial Trust', '15'],
#  ['Grab Holdings Ltd', '32'],
#  ['Keppel DC REIT', '29'],
#  ['Keppel Ltd', '16'],
#  ['Mapletree Industrial Trust', '7'],
#  ['Mapletree Logistics Trust', '34'],
#  ['Mapletree Pan Asia Commercial Trust', '20'],
#  ['Oversea\xadChinese Banking Corp Ltd', '106'],
#  ['Sembcorp Industries Ltd', '8'],
#  ['Singapore Exchange Ltd', '16'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Singapore Technologies Engineering Ltd', '11'],
#  ['Singapore Telecommunications Ltd', '41'],
#  ['United Overseas Bank Ltd', '93'],
#  ['Wilmar International Ltd', '13'],
#  ['Yangzijiang Shipbuilding Holdings Ltd', '13'],
#  ['Taiwan', '5.412'],
#  ['Accton Technology Corp', '94'],
#  ['Acer Inc', '1'],
#  ['Advancetek Enterprise Co Ltd', '3'],
#  ['Advantech Co Ltd', '1'],
#  ['Airoha Technology Corp', '3'],
#  ['Airtac International Group', '25'],
#  ['Alchip Technologies Ltd', '33'],
#  ['Andes Technology Corp', '12'],
#  ['Arcadyan Technology Corp', '6'],
#  ['ASE Technology Holding Co Ltd', '51'],
#  ['Asia Cement Corp', '14'],
#  ['Asia Vital Components Co Ltd', '14'],
#  ['ASMedia Technology Inc', '14'],
#  ['ASPEED Technology Inc', '12'],
#  ['Asustek Computer Inc', '15'],
#  ['Brighton-Best International Taiwan Inc', '1'],
#  ['Capital Securities Corp', '1'],
#  ['Catcher Technology Co Ltd', '1'],
#  ['Cathay Financial Holding Co Ltd', '14'],
#  ['Chailease Holding Co Ltd', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Cheng Shin Rubber Industry Co Ltd', '3'],
#  ['Chicony Electronics Co Ltd', '6'],
#  ['Chicony Power Technology Co Ltd', '4'],
#  ['Chief Telecom Inc', '19'],
#  ['China Airlines Ltd', '31'],
#  ['China Steel Corp', '1'],
#  ['Chroma ATE Inc', '79'],
#  ['Chunghwa Telecom Co Ltd', '3'],
#  ['Compal Electronics Inc', '44'],
#  ['CTBC Financial Holding Co Ltd', '64'],
#  ['Darfon Electronics Corp', '1'],
#  ['Delta Electronics Inc', '88'],
#  ['Depo Auto Parts Ind Co Ltd', '2'],
#  ['E Ink Holdings Inc', '29'],
#  ['E.Sun Financial Holding Co Ltd', '9'],
#  ['Elan Microelectronics Corp', '8'],
#  ['Elite Material Co Ltd', '16'],
#  ['eMemory Technology Inc', '48'],
#  ['Eternal Materials Co Ltd', '2'],
#  ['Eva Airways Corp', '36'],
#  ['Evergreen Marine Corp Taiwan Ltd', '29'],
#  ['Everlight Electronics Co Ltd', '1'],
#  ['Far Eastern New Century Corp', '6'],
#  ['Far EasTone Telecommunications Co Ltd', '3'],
#  ['First Financial Holding Co Ltd', '1'],
#  ['Formosa Plastics Corp', '1'],
#  ['Foxconn Technology Co Ltd', '3'],
#  ['Foxsemicon Integrated Technology Inc', '3'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Fubon Financial Holding Co Ltd', '126'],
#  ['Getac Holdings Corp', '1'],
#  ['Gigabyte Technology Co Ltd', '1'],
#  ['Global Unichip Corp', '3'],
#  ['Goldsun Building Materials Co Ltd', '1'],
#  ['Gourmet Master Co Ltd', '1'],
#  ['Hon Hai Precision Industry Co Ltd', '236'],
#  ['Hotai Motor Co Ltd', '1'],
#  ['Hua Nan Financial Holdings Co Ltd', '1'],
#  ['Huang Hsiang Construction Corp', '1'],
#  ['Innolux Corp', '1'],
#  ['International Games System Co Ltd', '16'],
#  ['Inventec Corp', '1'],
#  ['ITE Technology Inc', '6'],
#  ['Jinan Acetate Chemical Co Ltd', '2'],
#  ['KGI Financial Holding Co Ltd', '9'],
#  ['Kindom Development Co Ltd', '4'],
#  ['King Slide Works Co Ltd', '1'],
#  ['King Yuan Electronics Co Ltd', '20'],
#  ['Kinpo Electronics', '1'],
#  ['L&K Engineering Co Ltd', '3'],
#  ['Largan Precision Co Ltd', '25'],
#  ['Lite-On Technology Corp', '1'],
#  ['Lotes Co Ltd', '9'],
#  ['Makalot Industrial Co Ltd', '10'],
#  ['MediaTek Inc', '405'],
#  ['Mega Financial Holding Co Ltd', '2'],
#  ['Merida Industry Co Ltd', '13'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Micro\xadStar International Co Ltd', '1'],
#  ['Nan Pao Resins Chemical Co Ltd', '2'],
#  ['Nan Ya Plastics Corp', '1'],
#  ['Nien Made Enterprise Co Ltd', '3'],
#  ['Novatek Microelectronics Corp', '11'],
#  ['Pegatron Corp', '11'],
#  ['PharmaEssentia Corp', '1'],
#  ['Pixart Imaging Inc', '4'],
#  ['Pou Chen Corp', '13'],
#  ['Powertech Technology Inc', '4'],
#  ['Poya International Co Ltd', '2'],
#  ['President Chain Store Corp', '51'],
#  ['Primax Electronics Ltd', '4'],
#  ['Quanta Computer Inc', '9'],
#  ['Radiant Opto\xadElectronics Corp', '4'],
#  ['Raydium Semiconductor Corp', '2'],
#  ['Realtek Semiconductor Corp', '38'],
#  ['Shanghai Commercial & Savings Bank Ltd/The', '1'],
#  ['Shin Kong Financial Holding Co Ltd', '1'],
#  ['Silergy Corp', '49'],
#  ['SinoPac Financial Holdings Co Ltd', '6'],
#  ['Sunonwealth Electric Machine Industry Co Ltd', '2'],
#  ['Sunplus Technology Co Ltd', '4'],
#  ['Synnex Technology International Corp', '1'],
#  ['Taishin Financial Holding Co Ltd', '2'],
#  ['Taiwan Business Bank', '1'],
#  ['Taiwan Cooperative Financial Holding Co Ltd', '1'],
#  ['Taiwan Mobile Co Ltd', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Taiwan Semiconductor Manufacturing Co Ltd', '3.190'],
#  ['TCC Group Holdings Co Ltd', '1'],
#  ['Topco Scientific Co Ltd', '7'],
#  ['Tripod Technology Corp', '16'],
#  ['Tung Ho Steel Enterprise Corp', '2'],
#  ['Unimicron Technology Corp', '22'],
#  ['Uni\xadPresident Enterprises Corp', '63'],
#  ['United Integrated Services Co Ltd', '15'],
#  ['United Microelectronics Corp', '2'],
#  ['Vanguard International Semiconductor Corp', '1'],
#  ['Voltronic Power Technology Corp', '15'],
#  ['Wan Hai Lines Ltd', '2'],
#  ['Wistron Corp', '3'],
#  ['Wiwynn Corp', '41'],
#  ['Wowprime Corp', '3'],
#  ['WPG Holdings Ltd', '1'],
#  ['Yageo Corp', '14'],
#  ['Yang Ming Marine Transport Corp', '9'],
#  ['Yankey Engineering Co Ltd', '1'],
#  ['Yuanta Financial Holding Co Ltd', '22'],
#  ['Zhen Ding Technology Holding Ltd', '1'],
#  ['Thailand', '433'],
#  ['Advanced Info Service PCL', '1'],
#  ['Airports of Thailand PCL', '1'],
#  ['Amata Corp PCL', '4'],
#  ['Asia Aviation PCL', '1'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Bangkok Airways PCL', '3'],
#  ['Bangkok Bank PCL', '41'],
#  ['Bangkok Dusit Medical Services PCL', '42'],
#  ['Bumrungrad Hospital PCL', '8'],
#  ['Central Pattana PCL', '39'],
#  ['Charoen Pokphand Foods PCL', '22'],
#  ['CP ALL PCL', '35'],
#  ['CP AXTRA PCL', '1'],
#  ['Delta Electronics Thailand PCL', '6'],
#  ['Gulf Energy Development PCL', '1'],
#  ['Indorama Ventures PCL', '13'],
#  ['I-TAIL Corp PCL', '6'],
#  ['Kasikornbank PCL', '77'],
#  ['Krung Thai Bank PCL', '40'],
#  ['Minor International PCL', '1'],
#  ['Osotspa PCL', '2'],
#  ['SCB X PCL', '54'],
#  ['Siam Cement PCL/The', '1'],
#  ['SISB PCL', '14'],
#  ['Supalai PCL', '3'],
#  ['True Corp PCL', '16'],
#  ['Verenigde Arabische Emiraten', '542'],
#  ['Abu Dhabi Commercial Bank PJSC', '49'],
#  ['Abu Dhabi Islamic Bank PJSC', '26'],
#  ['Air Arabia PJSC', '1'],
#  ['Aldar Properties PJSC', '86'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Deyaar Development PJSC', '2'],
#  ['Dubai Islamic Bank PJSC', '12'],
#  ['Emaar Properties PJSC', '214'],
#  ['Emirates NBD PJSC', '69'],
#  ['Emirates Telecommunications Group Co PJSC', '8'],
#  ['First Abu Dhabi Bank PJSC', '18'],
#  ['Lulu Retail Holdings PLC', '3'],
#  ['Parkin Co PJSC', '12'],
#  ['Salik Co PJSC', '27'],
#  ['Talabat Holding PLC', '14'],
#  ['', ''],
#  ['Vietnam', '157'],
#  ['FPT Corp', '74'],
#  ['Hoa Phat Group JSC', '16'],
#  ['Masan Group Corp', '5'],
#  ['Military Commercial Joint Stock Bank', '4'],
#  ['Mobile World Investment Corp', '6'],
#  ['Vietnam Dairy Products JSC', '47'],
#  ['Vincom Retail JSC', '5'],
#  ['Zuid Korea', '2.740'],
#  ['Alteogen Inc', '15'],
#  ['Amorepacific Corp', '2'],
#  ['BNK Financial Group Inc', '10'],
#  ['Celltrion Inc', '18'],
#  ['Cheil Worldwide Inc', '8'],
#  ['CJ CheilJedang Corp', '4'],
#  ['Regio / Land / Uitgever', 'Waarde'],
#  ['Cosmax Inc', '22'],
#  ['Coupang Inc', '20'],
#  ['DB Insurance Co Ltd', '59'],
#  ['DGB Financial Group Inc', '7'],
#  ...]

# %%
for line in tabs3:
    if line == ['Regio / Land / Uitgever', 'Waarde'] or line == ['', '']:
        tabs3.remove(line)

tabs3
# Out:
# [['Beursgenoteerde', ''],
#  ['beleggingen', None],
#  ['Afrika', '625'],
#  ['Zuid-Afrika', '625'],
#  ['Absa Group Ltd', '5'],
#  ['Anglo American Platinum Ltd', '1'],
#  ['Anglogold Ashanti Plc', '29'],
#  ['Aspen Pharmacare Holdings Ltd', '1'],
#  ['AVI Ltd', '7'],
#  ['Bid Corp Ltd', '8'],
#  ['Bidvest Group Ltd', '1'],
#  ['Capitec Bank Holdings Ltd', '55'],
#  ['Clicks Group Ltd', '25'],
#  ['Discovery Ltd', '5'],
#  ['FirstRand Ltd', '90'],
#  ['Foschini Group Ltd', '1'],
#  ['Gold Fields Ltd', '85'],
#  ['Hyprop Investments Ltd', '2'],
#  ['Impala Platinum Holdings Ltd', '32'],
#  ['Investec Ltd', '8'],
#  ['Life Healthcare Group Holdings Ltd', '1'],
#  ['Momentum Group Ltd', '2'],
#  ['Mr Price Group Ltd', '9'],
#  ['MTN Group Ltd', '17'],
#  ['Naspers Ltd', '117'],
#  ['Nedbank Group Ltd', '6'],
#  ['NEPI Rockcastle NV', '4'],
#  ['Old Mutual Ltd', '5'],
#  ['Omnia Holdings Ltd', '1'],
#  ['OUTsurance Group Ltd', '16'],
#  ['Remgro Ltd', '1'],
#  ['Sanlam Ltd', '34'],
#  ['Sappi Ltd', '2'],
#  ['Shoprite Holdings Ltd', '33'],
#  ['Standard Bank Group Ltd', '22'],
#  ['Telkom SA SOC Ltd', '1'],
#  ['Vodacom Group Ltd', '1'],
#  ['Vukile Property Fund Ltd', '1'],
#  ['Woolworths Holdings Ltd/South Africa', '1'],
#  ['Azië', '34.689'],
#  ['China', '8.307'],
#  ['3SBio Inc', '6'],
#  ['AAC Technologies Holdings Inc', '19'],
#  ['Agricultural Bank of China Ltd', '60'],
#  ['Akeso Inc', '1'],
#  ['Alibaba Group Holding Ltd', '586'],
#  ['Anhui Conch Cement Co Ltd', '10'],
#  ['Anker Innovations Technology Co Ltd', '10'],
#  ['Atour Lifestyle Holdings Ltd', '17'],
#  ['Autohome Inc', '25'],
#  ['Baidu Inc', '54'],
#  ['Bank of China \xad Luxembourg Branch', '41'],
#  ['Bank of Communications Co Ltd', '2'],
#  ['Bank of Ningbo Co Ltd', '3'],
#  ['BeiGene Ltd', '2'],
#  ['Beijing Jingneng Clean Energy Co Ltd', '1'],
#  ['Beijing Kingsoft Office Software Inc', '1'],
#  ['Beijing New Building Materials PLC', '5'],
#  ['Beijing Oriental Yuhong Waterproof Technology Co Ltd', '15'],
#  ['Bilibili Inc', '13'],
#  ['BOC Aviation Ltd', '2'],
#  ['BOE Technology Group Co Ltd', '31'],
#  ['Bosideng International Holdings Ltd', '31'],
#  ['Centre Testing International Group Co Ltd', '26'],
#  ['CGN Power Co Ltd', '1'],
#  ['China BlueChemical Ltd', '4'],
#  ['China CITIC Bank Corp Ltd', '6'],
#  ['China Communications Services Corp Ltd', '2'],
#  ['China Construction Bank Corp', '242'],
#  ['China CSSC Holdings Ltd', '2'],
#  ['China Everbright Bank Co Ltd', '6'],
#  ['China Feihe Ltd', '6'],
#  ['China Galaxy Securities Co Ltd', '8'],
#  ['China Hongqiao Group Ltd', '13'],
#  ['China International Capital Corp Ltd', '16'],
#  ['China International Marine Containers Group Co Ltd', '1'],
#  ['China Life Insurance Co Ltd', '9'],
#  ['China Medical System Holdings Ltd', '7'],
#  ['China Meidong Auto Holdings Ltd', '4'],
#  ['China Mengniu Dairy Co Ltd', '17'],
#  ['China Merchants Bank Co Ltd', '179'],
#  ['China Merchants Shekou Industrial Zone Holdings Co Ltd', '8'],
#  ['China Minsheng Banking Corp Ltd', '1'],
#  ['China Nonferrous Mining Corp Ltd', '2'],
#  ['China Overseas Land & Investment Ltd', '72'],
#  ['China Overseas Property Holdings Ltd', '1'],
#  ['China Pacific Insurance Group Co Ltd', '51'],
#  ['China Railway Group Ltd', '1'],
#  ['China Resources Beer Holdings Co Ltd', '52'],
#  ['China Resources Beverage Holdings Co Ltd', '10'],
#  ['China Resources Gas Group Ltd', '12'],
#  ['China Resources Land Ltd', '470'],
#  ['China Resources Mixc Lifestyle Services Ltd', '3'],
#  ['China South Publishing & Media Group Co Ltd', '8'],
#  ['China State Construction International Holdings Ltd', '1'],
#  ['China Taiping Insurance Holdings Co Ltd', '13'],
#  ['China Tower Corp Ltd', '8'],
#  ['China Yangtze Power Co Ltd', '31'],
#  ['Chongqing Rural Commercial Bank Co Ltd', '6'],
#  ['Chow Tai Fook Jewellery Group Ltd', '4'],
#  ['CITIC Securities Co Ltd', '3'],
#  ['CMOC Group Ltd', '20'],
#  ['Consun Pharmaceutical Group Ltd', '7'],
#  ['Contemporary Amperex Technology Co Ltd', '283'],
#  ['COSCO SHIPPING Holdings Co Ltd', '1'],
#  ['Country Garden Services Holdings Co Ltd', '4'],
#  ['CRRC Corp Ltd', '9'],
#  ['CSPC Pharmaceutical Group Ltd', '1'],
#  ['Dongyue Group Ltd', '3'],
#  ['East Money Information Co Ltd', '3'],
#  ['ENN Energy Holdings Ltd', '68'],
#  ['FinVolution Group', '5'],
#  ['Founder Securities Co Ltd', '1'],
#  ['Full Truck Alliance Co Ltd', '44'],
#  ['Fuyao Glass Industry Group Co Ltd', '22'],
#  ['GCL Technology Holdings Ltd', '1'],
#  ['GDS Holdings Ltd', '14'],
#  ['Geely Automobile Holdings Ltd', '9'],
#  ['GF Securities Co Ltd', '8'],
#  ['Giant Biogene Holding Co ltd', '3'],
#  ['Gree Electric Appliances Inc of Zhuhai', '30'],
#  ['Greentown Service Group Co Ltd', '1'],
#  ['Guoyuan Securities Co Ltd', '4'],
#  ['H World Group Ltd', '23'],
#  ['Haidilao International Holding Ltd', '7'],
#  ['Haier Smart Home Co Ltd', '128'],
#  ['Haitong Securities Co Ltd', '1'],
#  ['Hansoh Pharmaceutical Group Co Ltd', '6'],
#  ['Hisense Home Appliances Group Co Ltd', '4'],
#  ['Hisense Visual Technology Co Ltd', '3'],
#  ['HLA Group Corp Ltd', '9'],
#  ['Huatai Securities Co Ltd', '17'],
#  ['Huaxia Bank Co Ltd', '33'],
#  ['Hubei Dinglong Co Ltd', '2'],
#  ['Hygon Information Technology Co Ltd', '11'],
#  ['Industrial & Commercial Bank Of China, Luxembourg Branch', '156'],
#  ['Inner Mongolia Yili Industrial Group Co Ltd', '85'],
#  ['Innovent Biologics Inc', '3'],
#  ['JD Health International Inc', '1'],
#  ['JD Logistics Inc', '2'],
#  ['JD.com Inc', '194'],
#  ['Jiangsu Hengrui Pharmaceuticals Co Ltd', '2'],
#  ['Jinduicheng Molybdenum Co Ltd', '5'],
#  ['JNBY Design Ltd', '1'],
#  ['Joincare Pharmaceutical Group Industry Co Ltd', '3'],
#  ['JOYY Inc', '3'],
#  ['Kanzhun Ltd', '3'],
#  ['KE Holdings Inc', '54'],
#  ['Kingdee International Software Group Co Ltd', '3'],
#  ['Kingnet Network Co Ltd', '9'],
#  ['Kingsoft Corp Ltd', '32'],
#  ['Kuaishou Technology', '100'],
#  ['Kweichow Moutai Co Ltd', '31'],
#  ['Lenovo Group Ltd', '59'],
#  ['Li Auto Inc', '71'],
#  ['Longfor Group Holdings Ltd', '31'],
#  ['Meituan', '431'],
#  ['Midea Group Co Ltd', '120'],
#  ['Minth Group Ltd', '18'],
#  ['MMG Ltd', '24'],
#  ['NARI Technology Co Ltd', '61'],
#  ['NetEase Cloud Music Inc', '1'],
#  ['NetEase Inc', '136'],
#  ['New China Life Insurance Co Ltd', '2'],
#  ['New Oriental Education & Technology Group Inc', '21'],
#  ['Ningbo Ronbay New Energy Technology Co Ltd', '17'],
#  ['NIO Inc', '1'],
#  ['Nongfu Spring Co Ltd', '1'],
#  ['Orient Securities Co Ltd/China', '5'],
#  ['PDD Holdings Inc', '205'],
#  ['PICC Property & Casualty Co Ltd', '80'],
#  ['Ping An Insurance Group Co of China Ltd', '315'],
#  ['Pop Mart International Group Ltd', '19'],
#  ['Postal Savings Bank of China Co Ltd', '6'],
#  ['Qifu Technology Inc', '40'],
#  ['Sany Heavy Industry Co Ltd', '47'],
#  ['SF Holding Co Ltd', '22'],
#  ['SG Micro Corp', '18'],
#  ['Shandong Himile Mechanical Science & Technology Co Ltd', '7'],
#  ['Shandong Hi\xadspeed Co Ltd', '15'],
#  ['Shandong Nanshan Aluminum Co Ltd', '14'],
#  ['Shandong Weigao Group Medical Polymer Co Ltd', '6'],
#  ['Shanghai Chicmax Cosmetic Co Ltd', '2'],
#  ['Shanghai Pudong Development Bank Co Ltd', '28'],
#  ['Shanghai Rural Commercial Bank Co Ltd', '1'],
#  ['Shenzhen Inovance Technology Co Ltd', '29'],
#  ['Shenzhen Mindray Bio\xadMedical Electronics Co Ltd', '44'],
#  ['Shenzhen New Industries Biomedical Engineering Co Ltd', '25'],
#  ['Shenzhou International Group Holdings Ltd', '31'],
#  ['Sieyuan Electric Co Ltd', '21'],
#  ['Sino Biopharmaceutical Ltd', '10'],
#  ['Sinopharm Group Co Ltd', '1'],
#  ['Sunac Services Holdings Ltd', '1'],
#  ['Sungrow Power Supply Co Ltd', '10'],
#  ['Sunny Optical Technology Group Co Ltd', '36'],
#  ['Sunwoda Electronic Co Ltd', '3'],
#  ['Tencent Holdings Ltd', '1.578'],
#  ['Tencent Music Entertainment Group', '29'],
#  ['Tingyi Cayman Islands Holding Corp', '21'],
#  ['Tongcheng Travel Holdings Ltd', '38'],
#  ['Tongwei Co Ltd', '25'],
#  ['Trip.com Group Ltd', '212'],
#  ['Tsingtao Brewery Co Ltd', '2'],
#  ['Universal Scientific Industrial Shanghai Co Ltd', '12'],
#  ['Vipshop Holdings Ltd', '34'],
#  ['Wanhua Chemical Group Co Ltd', '16'],
#  ['Want Want China Holdings Ltd', '1'],
#  ['Weichai Power Co Ltd', '44'],
#  ['Western Mining Co Ltd', '13'],
#  ['Will Semiconductor Co Ltd Shanghai', '9'],
#  ['Wuliangye Yibin Co Ltd', '43'],
#  ['WuXi AppTec Co Ltd', '1'],
#  ['Wuxi Biologics Cayman Inc', '9'],
#  ['Xiaomi Corp', '151'],
#  ['Xinyi Solar Holdings Ltd', '14'],
#  ['XPeng Inc', '4'],
#  ['Xtep International Holdings Ltd', '5'],
#  ['Yadea Group Holdings Ltd', '12'],
#  ['Yealink Network Technology Corp Ltd', '4'],
#  ['Yifeng Pharmacy Chain Co Ltd', '23'],
#  ['Yum China Holdings Inc', '13'],
#  ['Yunnan Yuntianhua Co Ltd', '29'],
#  ['Yutong Bus Co Ltd', '26'],
#  ['Zhejiang Longsheng Group Co Ltd', '28'],
#  ['Zhejiang Semir Garment Co Ltd', '1'],
#  ['Zhejiang Supor Co Ltd', '30'],
#  ['Zhongsheng Group Holdings Ltd', '21'],
#  ['Zijin Mining Group Co Ltd', '61'],
#  ['ZTE Corp', '19'],
#  ['ZTO Express Cayman Inc', '38'],
#  ['Filippijnen', '454'],
#  ['Ayala Land Inc', '59'],
#  ['Bank of the Philippine Islands', '26'],
#  ['BDO Unibank Inc', '34'],
#  ['Bloomberry Resorts Corp', '5'],
#  ['DigiPlus Interactive Corp', '1'],
#  ['International Container Terminal Services Inc', '18'],
#  ['Metropolitan Bank & Trust Co', '8'],
#  ['SM Investments Corp', '7'],
#  ['SM Prime Holdings Inc', '297'],
#  ['Hong Kong', '1.906'],
#  ['AIA Group Ltd', '182'],
#  ['CLP Holdings Ltd', '35'],
#  ['ESR Group Ltd', '309'],
#  ['Futu Holdings Ltd', '15'],
#  ['Hang Lung Properties Ltd', '88'],
#  ['Hang Seng Bank Ltd', '19'],
#  ['Henderson Land Development Co Ltd', '9'],
#  ['HKT Trust & HKT Ltd', '10'],
#  ['Hong Kong & China Gas Co Ltd', '18'],
#  ['Hong Kong Exchanges & Clearing Ltd', '99'],
#  ['Hongkong Land Holdings Ltd', '45'],
#  ['HSBC Holdings PLC', '480'],
#  ['Link REIT', '305'],
#  ['MTR Corp Ltd', '12'],
#  ['Sun Hung Kai Properties Ltd', '122'],
#  ['Swire Pacific Ltd', '8'],
#  ['Swire Properties Ltd', '18'],
#  ['Techtronic Industries Co Ltd', '43'],
#  ['Wharf Holdings Ltd/The', '3'],
#  ['Wharf Real Estate Investment Co Ltd', '88'],
#  ['India', '4.456'],
#  ['ABB India Ltd', '51'],
#  ['Alkem Laboratories Ltd', '3'],
#  ['Ambuja Cements Ltd', '1'],
#  ['Anant Raj Ltd', '4'],
#  ['Apollo Hospitals Enterprise Ltd', '37'],
#  ['Ashok Leyland Ltd', '1'],
#  ['Ashoka Buildcon Ltd', '6'],
#  ['Asian Paints Ltd', '2'],
#  ['Astral Ltd', '1'],
#  ['Aurobindo Pharma Ltd', '4'],
#  ['Avenue Supermarts Ltd', '1'],
#  ['Axis Bank Ltd', '117'],
#  ['Bajaj Auto Ltd', '23'],
#  ['Bajaj Finance Ltd', '47'],
#  ['Bajaj Finserv Ltd', '3'],
#  ['Bajaj Holdings & Investment Ltd', '1'],
#  ['Bajaj Housing Finance Ltd', '5'],
#  ['Balkrishna Industries Ltd', '1'],
#  ['Bank of Baroda', '24'],
#  ['Bharat Forge Ltd', '8'],
#  ['Bharti Airtel Ltd', '152'],
#  ['Bharti Hexacom Ltd', '25'],
#  ['Birlasoft Ltd', '2'],
#  ['Blue Star Ltd', '25'],
#  ['Britannia Industries Ltd', '8'],
#  ['Can Fin Homes Ltd', '1'],
#  ['Canara Bank', '11'],
#  ['Ceat Ltd', '5'],
#  ['CG Power & Industrial Solutions Ltd', '1'],
#  ['Chambal Fertilisers and Chemicals Ltd', '1'],
#  ['Cholamandalam Financial Holdings Ltd', '6'],
#  ['Cholamandalam Investment and Finance Co Ltd', '59'],
#  ['Cipla Ltd/India', '37'],
#  ['CMS Info Systems Ltd', '2'],
#  ['Coforge Ltd', '10'],
#  ['Colgate\xadPalmolive India Ltd', '28'],
#  ['Computer Age Management Services Ltd', '16'],
#  ['Craftsman Automation Ltd', '12'],
#  ['CRISIL Ltd', '3'],
#  ['Cummins India Ltd', '7'],
#  ['Dabur India Ltd', '1'],
#  ['Delhivery Ltd', '12'],
#  ['Divi’s Laboratories Ltd', '1'],
#  ['Dixon Technologies India Ltd', '15'],
#  ['DLF Ltd', '83'],
#  ['Dr Reddy’s Laboratories Ltd', '6'],
#  ['Edelweiss Financial Services Ltd', '1'],
#  ['Eicher Motors Ltd', '64'],
#  ['EID Parry India Ltd', '1'],
#  ['Embassy Office Parks REIT', '22'],
#  ['Entero Healthcare Solutions Ltd', '15'],
#  ['EPL Ltd', '2'],
#  ['Escorts Kubota Ltd', '10'],
#  ['Finolex Cables Ltd', '1'],
#  ['Force Motors Ltd', '2'],
#  ['Fortis Healthcare Ltd', '10'],
#  ['GlaxoSmithKline Pharmaceuticals Ltd', '1'],
#  ['Glenmark Pharmaceuticals Ltd', '22'],
#  ['Global Health Ltd/India', '15'],
#  ['GMR Airports Ltd', '30'],
#  ['Godawari Power and Ispat Ltd', '7'],
#  ['Godrej Consumer Products Ltd', '1'],
#  ['Godrej Properties Ltd', '72'],
#  ['Grasim Industries Ltd', '1'],
#  ['Gujarat Pipavav Port Ltd', '10'],
#  ['Gujarat State Petronet Ltd', '1'],
#  ['Havells India Ltd', '27'],
#  ['HCL Technologies Ltd', '83'],
#  ['HDFC Asset Management Co Ltd', '14'],
#  ['HDFC Bank Ltd', '416'],
#  ['HDFC Life Insurance Co Ltd', '23'],
#  ['Hero MotoCorp Ltd', '8'],
#  ['Hindalco Industries Ltd', '25'],
#  ['Hindustan Aeronautics Ltd', '39'],
#  ['Hindustan Unilever Ltd', '25'],
#  ['Home First Finance Co India Ltd', '6'],
#  ['ICICI Bank Ltd', '301'],
#  ['ICICI Lombard General Insurance Co Ltd', '10'],
#  ['ICICI Prudential Life Insurance Co Ltd', '17'],
#  ['ICICI Securities Ltd', '1'],
#  ['IIFL Finance Ltd', '1'],
#  ['IndiaMart InterMesh Ltd', '6'],
#  ['Indian Energy Exchange Ltd', '4'],
#  ['Indian Hotels Co Ltd/The', '63'],
#  ['Indraprastha Gas Ltd', '3'],
#  ['Indus Towers Ltd', '5'],
#  ['Info Edge India Ltd', '27'],
#  ['Infosys Ltd', '264'],
#  ['InterGlobe Aviation Ltd', '22'],
#  ['Inventurus Knowledge Solutions Ltd', '4'],
#  ['ITD Cementation India Ltd', '2'],
#  ['Jamna Auto Industries Ltd', '2'],
#  ['JB Chemicals & Pharmaceuticals Ltd', '4'],
#  ['Jio Financial Services Ltd', '17'],
#  ['JSW Steel Ltd', '1'],
#  ['Jubilant Foodworks Ltd', '1'],
#  ['Jyothy Labs Ltd', '1'],
#  ['Kalyan Jewellers India Ltd', '16'],
#  ['Karur Vysya Bank Ltd/The', '7'],
#  ['Kfin Technologies Ltd', '7'],
#  ['Kirloskar Brothers Ltd', '1'],
#  ['Kirloskar Oil Engines Ltd', '2'],
#  ['Kotak Mahindra Bank Ltd', '4'],
#  ['KPIT Technologies Ltd', '13'],
#  ['Lemon Tree Hotels Ltd', '198'],
#  ['LIC Housing Finance Ltd', '9'],
#  ['Lupin Ltd', '63'],
#  ['Macrotech Developers Ltd', '98'],
#  ['Mahanagar Gas Ltd', '20'],
#  ['Mahindra & Mahindra Ltd', '36'],
#  ['MakeMyTrip Ltd', '28'],
#  ['Manappuram Finance Ltd', '6'],
#  ['Mankind Pharma Ltd', '3'],
#  ['Marico Ltd', '1'],
#  ['Maruti Suzuki India Ltd', '4'],
#  ['Max Healthcare Institute Ltd', '49'],
#  ['Motilal Oswal Financial Services Ltd', '8'],
#  ['Mphasis Ltd', '10'],
#  ['MRF Ltd', '1'],
#  ['Multi Commodity Exchange of India Ltd', '9'],
#  ['Muthoot Finance Ltd', '3'],
#  ['NCC Ltd/India', '2'],
#  ['Nestle India Ltd', '1'],
#  ['NIIT Learning Systems Ltd', '1'],
#  ['Nippon Life India Asset Management Ltd', '3'],
#  ['NTPC Ltd', '20'],
#  ['Nuvama Wealth Management Ltd', '2'],
#  ['Oberoi Realty Ltd', '22'],
#  ['Oracle Financial Services Software Ltd', '5'],
#  ['Page Industries Ltd', '11'],
#  ['Paradeep Phosphates Ltd', '4'],
#  ['Patanjali Foods Ltd', '17'],
#  ['PB Fintech Ltd', '21'],
#  ['Persistent Systems Ltd', '29'],
#  ['Phoenix Mills Ltd/The', '44'],
#  ['PI Industries Ltd', '27'],
#  ['Pidilite Industries Ltd', '12'],
#  ['Piramal Enterprises Ltd', '2'],
#  ['PNB Housing Finance Ltd', '9'],
#  ['Polycab India Ltd', '4'],
#  ['Power Grid Corp of India Ltd', '122'],
#  ['Prestige Estates Projects Ltd', '46'],
#  ['PTC India Ltd', '8'],
#  ['Punjab National Bank', '5'],
#  ['Rainbow Children’s Medicare Ltd', '17'],
#  ['Ramco Cements Ltd/The', '1'],
#  ['Ramkrishna Forgings Ltd', '2'],
#  ['REC Ltd', '49'],
#  ['Reliance Infrastructure Ltd', '1'],
#  ['Samvardhana Motherson International Ltd', '16'],
#  ['SBI Life Insurance Co Ltd', '38'],
#  ['Shree Cement Ltd', '1'],
#  ['Shriram Finance Ltd', '41'],
#  ['SignatureGlobal India Ltd', '1'],
#  ['Sona Blw Precision Forgings Ltd', '15'],
#  ['SRF Ltd', '1'],
#  ['State Bank of India', '51'],
#  ['Sun Pharmaceutical Industries Ltd', '50'],
#  ['Supreme Industries Ltd', '4'],
#  ['Suzlon Energy Ltd', '1'],
#  ['Tata Consultancy Services Ltd', '179'],
#  ['Tata Elxsi Ltd', '1'],
#  ['Tata Motors Ltd', '23'],
#  ['Tata Power Co Ltd/The', '1'],
#  ['Tata Steel Ltd', '2'],
#  ['Tech Mahindra Ltd', '6'],
#  ['Titagarh Rail System Ltd', '6'],
#  ['Titan Co Ltd', '10'],
#  ['Torrent Pharmaceuticals Ltd', '49'],
#  ['Torrent Power Ltd', '1'],
#  ['Transport Corp of India Ltd', '1'],
#  ['Trent Ltd', '31'],
#  ['Triveni Turbine Ltd', '13'],
#  ['Tube Investments of India Ltd', '17'],
#  ['TVS Motor Co Ltd', '1'],
#  ['UltraTech Cement Ltd', '48'],
#  ['Union Bank of India Ltd', '5'],
#  ['United Spirits Ltd', '1'],
#  ['UPL Ltd', '30'],
#  ['Varun Beverages Ltd', '58'],
#  ['Vodafone Idea Ltd', '10'],
#  ['Voltas Ltd', '1'],
#  ['Welspun Living Ltd', '1'],
#  ['Westlife Foodworld Ltd', '13'],
#  ['Wipro Ltd', '9'],
#  ['Zensar Technologies Ltd', '4'],
#  ['Zomato Ltd', '55'],
#  ['Indonesië', '508'],
#  ['Amman Mineral Internasional PT', '1'],
#  ['Aspirasi Hidup Indonesia Tbk PT', '1'],
#  ['Bank Central Asia Tbk PT', '139'],
#  ['Bank Mandiri Persero Tbk PT', '48'],
#  ['Bank Negara Indonesia Persero Tbk PT', '66'],
#  ['Bank Rakyat Indonesia Persero Tbk PT', '133'],
#  ['Chandra Asri Pacific Tbk PT', '1'],
#  ['Daya Intiguna Yasa Tbk PT', '13'],
#  ['GoTo Gojek Tokopedia Tbk PT', '1'],
#  ['Indosat Tbk PT', '20'],
#  ['Japfa Comfeed Indonesia Tbk PT', '2'],
#  ['Semen Indonesia Persero Tbk PT', '8'],
#  ['Sumber Alfaria Trijaya Tbk PT', '20'],
#  ['Telkom Indonesia Persero Tbk PT', '35'],
#  ['Vale Indonesia Tbk PT', '22'],
#  ['Israël', '72'],
#  ['Azrieli Group Ltd', '5'],
#  ['Check Point Software Technologies Ltd', '39'],
#  ['Nova Ltd', '12'],
#  ['Phoenix Financial Ltd', '3'],
#  ['Tower Semiconductor Ltd', '12'],
#  ['Japan', '7.686'],
#  ['Advantest Corp', '71'],
#  ['Aeon Co Ltd', '45'],
#  ['Air Water Inc', '6'],
#  ['Aisin Corp', '16'],
#  ['Ajinomoto Co Inc', '47'],
#  ['Amada Co Ltd', '7'],
#  ['ANA Holdings Inc', '6'],
#  ['Asahi Intecc Co Ltd', '9'],
#  ['Asahi Kasei Corp', '21'],
#  ['Asics Corp', '35'],
#  ['Astellas Pharma Inc', '41'],
#  ['Azbil Corp', '9'],
#  ['Bridgestone Corp', '48'],
#  ['Brother Industries Ltd', '10'],
#  ['Central Japan Railway Co', '85'],
#  ['Chiba Bank Ltd/The', '12'],
#  ['Chugai Pharmaceutical Co Ltd', '68'],
#  ['Concordia Financial Group Ltd', '14'],
#  ['Dai Nippon Printing Co Ltd', '15'],
#  ['Daifuku Co Ltd', '44'],
#  ['Dai\xadichi Life Holdings Inc', '57'],
#  ['Daiichi Sankyo Co Ltd', '120'],
#  ['Daito Trust Construction Co Ltd', '15'],
#  ['Daiwa House Industry Co Ltd', '47'],
#  ['Daiwa House REIT Investment Corp', '26'],
#  ['Daiwa Securities Group Inc', '20'],
#  ['Dentsu Group Inc', '12'],
#  ['Disco Corp', '420'],
#  ['East Japan Railway Co', '46'],
#  ['Ebara Corp', '16'],
#  ['Eisai Co Ltd', '18'],
#  ['FANUC Corp', '55'],
#  ['Fast Retailing Co Ltd', '192'],
#  ['Fuji Electric Co Ltd', '18'],
#  ['FUJIFILM Holdings Corp', '60'],
#  ['Fujikura Ltd', '25'],
#  ['Fujitsu Ltd', '74'],
#  ['Fukuoka Financial Group Inc', '10'],
#  ['GLP J\xadReit', '8'],
#  ['Hankyu Hanshin Holdings Inc', '14'],
#  ['Haseko Corp', '8'],
#  ['Hikari Tsushin Inc', '9'],
#  ['Hirose Electric Co Ltd', '8'],
#  ['Hoshizaki Corp', '10'],
#  ['Hoya Corp', '99'],
#  ['Hulic Co Ltd', '38'],
#  ['Ibiden Co Ltd', '10'],
#  ['IHI Corp', '20'],
#  ['Internet Initiative Japan Inc', '6'],
#  ['Invincible Investment Corp', '15'],
#  ['Isetan Mitsukoshi Holdings Ltd', '15'],
#  ['Isuzu Motors Ltd', '20'],
#  ['Japan Airport Terminal Co Ltd', '6'],
#  ['Japan Exchange Group Inc', '27'],
#  ['Japan Hotel REIT Investment Corp', '12'],
#  ['Japan Metropolitan Fund Invest', '9'],
#  ['Japan Post Bank Co Ltd', '29'],
#  ['Japan Real Estate Investment Corp', '8'],
#  ['Kajima Corp', '19'],
#  ['Kansai Electric Power Co Inc/The', '22'],
#  ['Kansai Paint Co Ltd', '6'],
#  ['Kao Corp', '44'],
#  ['Kawasaki Kisen Kaisha Ltd', '14'],
#  ['KDX Realty Investment Corp', '35'],
#  ['Keio Corp', '6'],
#  ['Keisei Electric Railway Co Ltd', '10'],
#  ['Keyence Corp', '192'],
#  ['Kintetsu Group Holdings Co Ltd', '9'],
#  ['Kobe Bussan Co Ltd', '8'],
#  ['Koito Manufacturing Co Ltd', '7'],
#  ['Komatsu Ltd', '61'],
#  ['Konami Group Corp', '21'],
#  ['Kubota Corp', '32'],
#  ['Kuraray Co Ltd', '10'],
#  ['Kurita Water Industries Ltd', '9'],
#  ['Kyoto Financial Group Inc', '9'],
#  ['Kyowa Kirin Co Ltd', '8'],
#  ['Kyushu Railway Co', '8'],
#  ['Lasertec Corp', '20'],
#  ['Lixil Corp', '7'],
#  ['LY Corp', '16'],
#  ['M3 Inc', '9'],
#  ['Makita Corp', '19'],
#  ['Marui Group Co Ltd', '7'],
#  ['MatsukiyoCocokara & Co', '13'],
#  ['Mazda Motor Corp', '9'],
#  ['McDonald’s Holdings Co Japan Ltd', '7'],
#  ['Mebuki Financial Group Inc', '9'],
#  ['Medipal Holdings Corp', '7'],
#  ['MINEBEA MITSUMI Inc', '14'],
#  ['MISUMI Group Inc', '10'],
#  ['Mitsubishi Chemical Group Corp', '16'],
#  ['Mitsubishi Electric Corp', '82'],
#  ['Mitsubishi Estate Co Ltd', '67'],
#  ['Mitsubishi HC Capital Inc', '16'],
#  ['Mitsubishi Heavy Industries Ltd', '107'],
#  ['Mitsubishi UFJ Financial Group Inc', '316'],
#  ['Mitsui Chemicals Inc', '9'],
#  ['Mitsui Fudosan Co Ltd', '66'],
#  ['Mitsui Fudosan Logistics Park Inc', '20'],
#  ['Mitsui OSK Lines Ltd', '28'],
#  ['Miura Co Ltd', '5'],
#  ['Mizuho Financial Group Inc', '140'],
#  ['MonotaRO Co Ltd', '9'],
#  ['MS&AD Insurance Group Holdings Inc', '72'],
#  ['Murata Manufacturing Co Ltd', '69'],
#  ['Nexon Co Ltd', '11'],
#  ['NGK Insulators Ltd', '9'],
#  ['Nichirei Corp', '8'],
#  ['Nidec Corp', '44'],
#  ['Nikon Corp', '8'],
#  ['Nintendo Co Ltd', '154'],
#  ['Nippon Building Fund Inc', '11'],
#  ['Nippon Paint Holdings Co Ltd', '15'],
#  ['Nippon Prologis REIT Inc', '26'],
#  ['Nippon Telegraph & Telephone Corp', '67'],
#  ['Nippon Yusen KK', '36'],
#  ['Nissan Motor Co Ltd', '15'],
#  ['Nissin Foods Holdings Co Ltd', '13'],
#  ['Niterra Co Ltd', '14'],
#  ['Nitori Holdings Co Ltd', '25'],
#  ['Nomura Holdings Inc', '41'],
#  ['Nomura Real Estate Holdings Inc', '6'],
#  ['Nomura Real Estate Master Fund Inc', '6'],
#  ['Nomura Research Institute Ltd', '33'],
#  ['NTT Data Group Corp', '25'],
#  ['Obic Co Ltd', '23'],
#  ['Odakyu Electric Railway Co Ltd', '7'],
#  ['Olympus Corp', '41'],
#  ['Omron Corp', '15'],
#  ['Ono Pharmaceutical Co Ltd', '11'],
#  ['Open House Group Co Ltd', '6'],
#  ['Oracle Corp Japan', '7'],
#  ['Orix JREIT Inc', '15'],
#  ['Osaka Gas Co Ltd', '20'],
#  ['Otsuka Corp', '13'],
#  ['Otsuka Holdings Co Ltd', '62'],
#  ['Pan Pacific International Holdings Corp', '24'],
#  ['Panasonic Holdings Corp', '57'],
#  ['Persol Holdings Co Ltd', '6'],
#  ['Recruit Holdings Co Ltd', '243'],
#  ['Renesas Electronics Corp', '56'],
#  ['Resona Holdings Inc', '40'],
#  ['Ricoh Co Ltd', '15'],
#  ['Rohm Co Ltd', '7'],
#  ['Rohto Pharmaceutical Co Ltd', '9'],
#  ['Sanrio Co Ltd', '16'],
#  ['Sanwa Holdings Corp', '13'],
#  ['Sapporo Holdings Ltd', '9'],
#  ['SCREEN Holdings Co Ltd', '14'],
#  ['SCSK Corp', '7'],
#  ['Secom Co Ltd', '33'],
#  ['Sega Sammy Holdings Inc', '7'],
#  ['Seibu Holdings Inc', '11'],
#  ['Seiko Epson Corp', '13'],
#  ['Sekisui Chemical Co Ltd', '16'],
#  ['Sekisui House Ltd', '37'],
#  ['Shimadzu Corp', '18'],
#  ['Shimano Inc', '51'],
#  ['Shimizu Corp', '11'],
#  ['Shin\xadEtsu Chemical Co Ltd', '152'],
#  ['Shionogi & Co Ltd', '29'],
#  ['Shiseido Co Ltd', '16'],
#  ['Shizuoka Financial Group Inc', '10'],
#  ['Skylark Holdings Co Ltd', '8'],
#  ['SMC Corp', '54'],
#  ['Socionext Inc', '7'],
#  ['SoftBank Group Corp', '138'],
#  ['Sohgo Security Services Co Ltd', '6'],
#  ['Sompo Holdings Inc', '115'],
#  ['Sony Group Corp', '304'],
#  ['Square Enix Holdings Co Ltd', '8'],
#  ['SUMCO Corp', '6'],
#  ['Sumitomo Electric Industries Ltd', '33'],
#  ['Sumitomo Forestry Co Ltd', '15'],
#  ['Sumitomo Metal Mining Co Ltd', '14'],
#  ['Sumitomo Mitsui Financial Group Inc', '213'],
#  ['Sumitomo Mitsui Trust Group Inc', '40'],
#  ['Sumitomo Realty & Development Co Ltd', '35'],
#  ['Suntory Beverage & Food Ltd', '9'],
#  ['Sysmex Corp', '21'],
#  ['T&D Holdings Inc', '22'],
#  ['Taisei Corp', '17'],
#  ['Takeda Pharmaceutical Co Ltd', '95'],
#  ['TDK Corp', '43'],
#  ['Terumo Corp', '66'],
#  ['TIS Inc', '12'],
#  ['Tobu Railway Co Ltd', '7'],
#  ['Tohoku Electric Power Co Inc', '8'],
#  ['Tokio Marine Holdings Inc', '163'],
#  ['Tokyo Electron Ltd', '120'],
#  ['Tokyo Ohka Kogyo Co Ltd', '6'],
#  ['Tokyo Tatemono Co Ltd', '27'],
#  ['Tokyu Corp', '15'],
#  ['Tokyu Fudosan Holdings Corp', '22'],
#  ['Toray Industries Inc', '23'],
#  ['Tosoh Corp', '9'],
#  ['TOTO Ltd', '9'],
#  ['Toyota Industries Corp', '38'],
#  ['Toyota Tsusho Corp', '28'],
#  ['USS Co Ltd', '9'],
#  ['West Japan Railway Co', '19'],
#  ['Yamaha Corp', '8'],
#  ['Yamaha Motor Co Ltd', '19'],
#  ['Yaskawa Electric Corp', '231'],
#  ['Yokogawa Electric Corp', '13'],
#  ['Yokohama Rubber Co Ltd/The', '8'],
#  ['ZOZO Inc', '9'],
#  ['Kazachstan', '97'],
#  ['Kaspi.KZ JSC', '97'],
#  ['Koeweit', '67'],
#  ['Ali Alghanim Sons Automotive Co KSCC', '1'],
#  ['Boursa Kuwait Securities Co KPSC', '1'],
#  ['Gulf Bank KSCP', '1'],
#  ['Kuwait Finance House KSCP', '32'],
#  ['Kuwait Telecommunications Co', '1'],
#  ['Mobile Telecommunications Co KSCP', '3'],
#  ['National Bank of Kuwait SAKP', '30'],
#  ['Maleisië', '229'],
#  ['AMMB Holdings Bhd', '9'],
#  ['Bursa Malaysia Bhd', '5'],
#  ['CIMB Group Holdings Bhd', '93'],
#  ['Frontken Corp Bhd', '19'],
#  ['Gamuda Bhd', '13'],
#  ['Hartalega Holdings Bhd', '8'],
#  ['Hong Leong Bank Bhd', '18'],
#  ['IHH Healthcare Bhd', '1'],
#  ['IOI Properties Group Bhd', '2'],
#  ['Malayan Banking Bhd', '5'],
#  ['MR DIY Group M Bhd', '9'],
#  ['My EG Services Bhd', '2'],
#  ['Petronas Chemicals Group Bhd', '1'],
#  ['Petronas Gas Bhd', '1'],
#  ['Public Bank Bhd', '4'],
#  ['RHB Bank Bhd', '2'],
#  ['Scientex BHD', '2'],
#  ['SP Setia Bhd Group', '3'],
#  ['Telekom Malaysia Bhd', '4'],
#  ['Tenaga Nasional Bhd', '12'],
#  ['Top Glove Corp Bhd', '8'],
#  ['YTL Power International Bhd', '11'],
#  ['Qatar', '45'],
#  ['Commercial Bank Of Qatar Qsc/The', '1'],
#  ['Industries Qatar QSC', '3'],
#  ['Masraf Al Rayan QSC', '1'],
#  ['Qatar International Islamic Bank QSC', '1'],
#  ['Qatar Islamic Bank QPSC', '14'],
#  ['Qatar National Bank QPSC', '25'],
#  ['Saoedi-Arabië', '726'],
#  ['ACWA Power Co', '10'],
#  ['Al Rajhi Bank', '187'],
#  ['Alinma Bank', '7'],
#  ['Almarai Co JSC', '8'],
#  ['Arab National Bank', '38'],
#  ['Arabian Internet & Communications Services Co', '4'],
#  ['Bank AlBilad', '1'],
#  ['Banque Saudi Fransi', '7'],
#  ['Bupa Arabia for Cooperative Insurance Co', '4'],
#  ['Co for Cooperative Insurance/The', '12'],
#  ['Dr Sulaiman Al Habib Medical Services Group Co', '24'],
#  ['Elm Co', '40'],
#  ['Etihad Etisalat Co', '80'],
#  ['Leejam Sports Co JSC', '7'],
#  ['Mouwasat Medical Services Co', '12'],
#  ['Riyad Bank', '37'],
#  ['Riyadh Cables Group Co', '15'],
#  ['Saudi Arabian Mining Co', '20'],
#  ['Saudi Awwal Bank', '67'],
#  ['Saudi Basic Industries Corp', '17'],
#  ['Saudi Electricity Co', '3'],
#  ['Saudi Investment Bank/The', '1'],
#  ['Saudi National Bank/The', '55'],
#  ['Saudi Research & Media Group', '1'],
#  ['Saudi Tadawul Group Holding Co', '5'],
#  ['Saudi Telecom Co', '45'],
#  ['United Electronics Co', '15'],
#  ['Yanbu National Petrochemical Co', '3'],
#  ['Singapore', '855'],
#  ['CapitaLand Ascendas REIT', '61'],
#  ['CapitaLand Ascott Trust', '8'],
#  ['CapitaLand Integrated Commercial Trust', '76'],
#  ['Capitaland Investment Ltd/Singapore', '49'],
#  ['DBS Group Holdings Ltd', '199'],
#  ['Digital Core REIT Management Pte Ltd', '8'],
#  ['Frasers Logistics & Commercial Trust', '15'],
#  ['Grab Holdings Ltd', '32'],
#  ['Keppel DC REIT', '29'],
#  ['Keppel Ltd', '16'],
#  ['Mapletree Industrial Trust', '7'],
#  ['Mapletree Logistics Trust', '34'],
#  ['Mapletree Pan Asia Commercial Trust', '20'],
#  ['Oversea\xadChinese Banking Corp Ltd', '106'],
#  ['Sembcorp Industries Ltd', '8'],
#  ['Singapore Exchange Ltd', '16'],
#  ['Singapore Technologies Engineering Ltd', '11'],
#  ['Singapore Telecommunications Ltd', '41'],
#  ['United Overseas Bank Ltd', '93'],
#  ['Wilmar International Ltd', '13'],
#  ['Yangzijiang Shipbuilding Holdings Ltd', '13'],
#  ['Taiwan', '5.412'],
#  ['Accton Technology Corp', '94'],
#  ['Acer Inc', '1'],
#  ['Advancetek Enterprise Co Ltd', '3'],
#  ['Advantech Co Ltd', '1'],
#  ['Airoha Technology Corp', '3'],
#  ['Airtac International Group', '25'],
#  ['Alchip Technologies Ltd', '33'],
#  ['Andes Technology Corp', '12'],
#  ['Arcadyan Technology Corp', '6'],
#  ['ASE Technology Holding Co Ltd', '51'],
#  ['Asia Cement Corp', '14'],
#  ['Asia Vital Components Co Ltd', '14'],
#  ['ASMedia Technology Inc', '14'],
#  ['ASPEED Technology Inc', '12'],
#  ['Asustek Computer Inc', '15'],
#  ['Brighton-Best International Taiwan Inc', '1'],
#  ['Capital Securities Corp', '1'],
#  ['Catcher Technology Co Ltd', '1'],
#  ['Cathay Financial Holding Co Ltd', '14'],
#  ['Chailease Holding Co Ltd', '1'],
#  ['Cheng Shin Rubber Industry Co Ltd', '3'],
#  ['Chicony Electronics Co Ltd', '6'],
#  ['Chicony Power Technology Co Ltd', '4'],
#  ['Chief Telecom Inc', '19'],
#  ['China Airlines Ltd', '31'],
#  ['China Steel Corp', '1'],
#  ['Chroma ATE Inc', '79'],
#  ['Chunghwa Telecom Co Ltd', '3'],
#  ['Compal Electronics Inc', '44'],
#  ['CTBC Financial Holding Co Ltd', '64'],
#  ['Darfon Electronics Corp', '1'],
#  ['Delta Electronics Inc', '88'],
#  ['Depo Auto Parts Ind Co Ltd', '2'],
#  ['E Ink Holdings Inc', '29'],
#  ['E.Sun Financial Holding Co Ltd', '9'],
#  ['Elan Microelectronics Corp', '8'],
#  ['Elite Material Co Ltd', '16'],
#  ['eMemory Technology Inc', '48'],
#  ['Eternal Materials Co Ltd', '2'],
#  ['Eva Airways Corp', '36'],
#  ['Evergreen Marine Corp Taiwan Ltd', '29'],
#  ['Everlight Electronics Co Ltd', '1'],
#  ['Far Eastern New Century Corp', '6'],
#  ['Far EasTone Telecommunications Co Ltd', '3'],
#  ['First Financial Holding Co Ltd', '1'],
#  ['Formosa Plastics Corp', '1'],
#  ['Foxconn Technology Co Ltd', '3'],
#  ['Foxsemicon Integrated Technology Inc', '3'],
#  ['Fubon Financial Holding Co Ltd', '126'],
#  ['Getac Holdings Corp', '1'],
#  ['Gigabyte Technology Co Ltd', '1'],
#  ['Global Unichip Corp', '3'],
#  ['Goldsun Building Materials Co Ltd', '1'],
#  ['Gourmet Master Co Ltd', '1'],
#  ['Hon Hai Precision Industry Co Ltd', '236'],
#  ['Hotai Motor Co Ltd', '1'],
#  ['Hua Nan Financial Holdings Co Ltd', '1'],
#  ['Huang Hsiang Construction Corp', '1'],
#  ['Innolux Corp', '1'],
#  ['International Games System Co Ltd', '16'],
#  ['Inventec Corp', '1'],
#  ['ITE Technology Inc', '6'],
#  ['Jinan Acetate Chemical Co Ltd', '2'],
#  ['KGI Financial Holding Co Ltd', '9'],
#  ['Kindom Development Co Ltd', '4'],
#  ['King Slide Works Co Ltd', '1'],
#  ['King Yuan Electronics Co Ltd', '20'],
#  ['Kinpo Electronics', '1'],
#  ['L&K Engineering Co Ltd', '3'],
#  ['Largan Precision Co Ltd', '25'],
#  ['Lite-On Technology Corp', '1'],
#  ['Lotes Co Ltd', '9'],
#  ['Makalot Industrial Co Ltd', '10'],
#  ['MediaTek Inc', '405'],
#  ['Mega Financial Holding Co Ltd', '2'],
#  ['Merida Industry Co Ltd', '13'],
#  ['Micro\xadStar International Co Ltd', '1'],
#  ['Nan Pao Resins Chemical Co Ltd', '2'],
#  ['Nan Ya Plastics Corp', '1'],
#  ['Nien Made Enterprise Co Ltd', '3'],
#  ['Novatek Microelectronics Corp', '11'],
#  ['Pegatron Corp', '11'],
#  ['PharmaEssentia Corp', '1'],
#  ['Pixart Imaging Inc', '4'],
#  ['Pou Chen Corp', '13'],
#  ['Powertech Technology Inc', '4'],
#  ['Poya International Co Ltd', '2'],
#  ['President Chain Store Corp', '51'],
#  ['Primax Electronics Ltd', '4'],
#  ['Quanta Computer Inc', '9'],
#  ['Radiant Opto\xadElectronics Corp', '4'],
#  ['Raydium Semiconductor Corp', '2'],
#  ['Realtek Semiconductor Corp', '38'],
#  ['Shanghai Commercial & Savings Bank Ltd/The', '1'],
#  ['Shin Kong Financial Holding Co Ltd', '1'],
#  ['Silergy Corp', '49'],
#  ['SinoPac Financial Holdings Co Ltd', '6'],
#  ['Sunonwealth Electric Machine Industry Co Ltd', '2'],
#  ['Sunplus Technology Co Ltd', '4'],
#  ['Synnex Technology International Corp', '1'],
#  ['Taishin Financial Holding Co Ltd', '2'],
#  ['Taiwan Business Bank', '1'],
#  ['Taiwan Cooperative Financial Holding Co Ltd', '1'],
#  ['Taiwan Mobile Co Ltd', '1'],
#  ['Taiwan Semiconductor Manufacturing Co Ltd', '3.190'],
#  ['TCC Group Holdings Co Ltd', '1'],
#  ['Topco Scientific Co Ltd', '7'],
#  ['Tripod Technology Corp', '16'],
#  ['Tung Ho Steel Enterprise Corp', '2'],
#  ['Unimicron Technology Corp', '22'],
#  ['Uni\xadPresident Enterprises Corp', '63'],
#  ['United Integrated Services Co Ltd', '15'],
#  ['United Microelectronics Corp', '2'],
#  ['Vanguard International Semiconductor Corp', '1'],
#  ['Voltronic Power Technology Corp', '15'],
#  ['Wan Hai Lines Ltd', '2'],
#  ['Wistron Corp', '3'],
#  ['Wiwynn Corp', '41'],
#  ['Wowprime Corp', '3'],
#  ['WPG Holdings Ltd', '1'],
#  ['Yageo Corp', '14'],
#  ['Yang Ming Marine Transport Corp', '9'],
#  ['Yankey Engineering Co Ltd', '1'],
#  ['Yuanta Financial Holding Co Ltd', '22'],
#  ['Zhen Ding Technology Holding Ltd', '1'],
#  ['Thailand', '433'],
#  ['Advanced Info Service PCL', '1'],
#  ['Airports of Thailand PCL', '1'],
#  ['Amata Corp PCL', '4'],
#  ['Asia Aviation PCL', '1'],
#  ['Bangkok Airways PCL', '3'],
#  ['Bangkok Bank PCL', '41'],
#  ['Bangkok Dusit Medical Services PCL', '42'],
#  ['Bumrungrad Hospital PCL', '8'],
#  ['Central Pattana PCL', '39'],
#  ['Charoen Pokphand Foods PCL', '22'],
#  ['CP ALL PCL', '35'],
#  ['CP AXTRA PCL', '1'],
#  ['Delta Electronics Thailand PCL', '6'],
#  ['Gulf Energy Development PCL', '1'],
#  ['Indorama Ventures PCL', '13'],
#  ['I-TAIL Corp PCL', '6'],
#  ['Kasikornbank PCL', '77'],
#  ['Krung Thai Bank PCL', '40'],
#  ['Minor International PCL', '1'],
#  ['Osotspa PCL', '2'],
#  ['SCB X PCL', '54'],
#  ['Siam Cement PCL/The', '1'],
#  ['SISB PCL', '14'],
#  ['Supalai PCL', '3'],
#  ['True Corp PCL', '16'],
#  ['Verenigde Arabische Emiraten', '542'],
#  ['Abu Dhabi Commercial Bank PJSC', '49'],
#  ['Abu Dhabi Islamic Bank PJSC', '26'],
#  ['Air Arabia PJSC', '1'],
#  ['Aldar Properties PJSC', '86'],
#  ['Deyaar Development PJSC', '2'],
#  ['Dubai Islamic Bank PJSC', '12'],
#  ['Emaar Properties PJSC', '214'],
#  ['Emirates NBD PJSC', '69'],
#  ['Emirates Telecommunications Group Co PJSC', '8'],
#  ['First Abu Dhabi Bank PJSC', '18'],
#  ['Lulu Retail Holdings PLC', '3'],
#  ['Parkin Co PJSC', '12'],
#  ['Salik Co PJSC', '27'],
#  ['Talabat Holding PLC', '14'],
#  ['Vietnam', '157'],
#  ['FPT Corp', '74'],
#  ['Hoa Phat Group JSC', '16'],
#  ['Masan Group Corp', '5'],
#  ['Military Commercial Joint Stock Bank', '4'],
#  ['Mobile World Investment Corp', '6'],
#  ['Vietnam Dairy Products JSC', '47'],
#  ['Vincom Retail JSC', '5'],
#  ['Zuid Korea', '2.740'],
#  ['Alteogen Inc', '15'],
#  ['Amorepacific Corp', '2'],
#  ['BNK Financial Group Inc', '10'],
#  ['Celltrion Inc', '18'],
#  ['Cheil Worldwide Inc', '8'],
#  ['CJ CheilJedang Corp', '4'],
#  ['Cosmax Inc', '22'],
#  ['Coupang Inc', '20'],
#  ['DB Insurance Co Ltd', '59'],
#  ['DGB Financial Group Inc', '7'],
#  ['Eo Technics Co Ltd', '9'],
#  ['Hana Financial Group Inc', '108'],
#  ['Hankook Tire & Technology Co Ltd', '30'],
#  ['Hansol Chemical Co Ltd', '6'],
#  ['Hanwha Aerospace Co Ltd', '7'],
#  ['Hanwha Engine', '1'],
#  ['HD Hyundai Electric Co Ltd', '52'],
#  ['HD HYUNDAI MIPO', '9'],
#  ['HLB Inc', '1'],
#  ['HMM Co Ltd', '1'],
#  ['Hyundai Glovis Co Ltd', '22'],
#  ['Hyundai Marine & Fire Insurance Co Ltd', '7'],
#  ['Hyundai Mobis Co Ltd', '66'],
#  ['Hyundai Motor Co', '69'],
#  ['Hyundai Rotem Co Ltd', '12'],
#  ['Industrial Bank of Korea', '5'],
#  ['JYP Entertainment Corp', '2'],
#  ['Kakao Corp', '3'],
#  ['KB Financial Group Inc', '198'],
#  ['KCC Corp', '2'],
#  ['KEPCO Engineering & Construction Co Inc', '1'],
#  ['Kia Corp', '77'],
#  ['Koh Young Technology Inc', '9'],
#  ['Korea Aerospace Industries Ltd', '1'],
#  ['Korea Investment Holdings Co Ltd', '3'],
#  ['Korea Zinc Co Ltd', '1'],
#  ['Krafton Inc', '28'],
#  ['KT Corp', '2'],
#  ['Kumho Petrochemical Co Ltd', '1'],
#  ['LG Chem Ltd', '7'],
#  ['LG Corp', '1'],
#  ['LG Electronics Inc', '22'],
#  ['LG Energy Solution Ltd', '10'],
#  ['LG H&H Co Ltd', '9'],
#  ['Mirae Asset Securities Co Ltd', '2'],
#  ['NAVER Corp', '91'],
#  ['NH Investment & Securities Co Ltd', '2'],
#  ['Orion Corp/Republic of Korea', '12'],
#  ['Park Systems Corp', '9'],
#  ['Peptron Inc', '3'],
#  ['POSCO Holdings Inc', '4'],
#  ['Samsung Biologics Co Ltd', '46'],
#  ['Samsung C&T Corp', '17'],
#  ...]

# %%
table = pd.DataFrame(tabs3[2:], columns=['Publisher', 'Value in Millions of Euros'])
table
# Out:
#                           Publisher Value in Millions of Euros
# 0                            Afrika                        625
# 1                       Zuid-Afrika                        625
# 2                    Absa Group Ltd                          5
# 3       Anglo American Platinum Ltd                          1
# 4             Anglogold Ashanti Plc                         29
# ...                             ...                        ...
# 2082                           Peru                        226
# 2083  Cia de Minas Buenaventura SAA                          3
# 2084                  Credicorp Ltd                        139
# 2085           Southern Copper Corp                         85
# 2086                         Totaal                    181.555
#
# [2087 rows x 2 columns]

# %%
table2 = table.drop([0, 1, 37, 38, 228, 238, 259, 447, 463, 469, 678, 680, 688, 711, 718, 747, 769, 895, 921, 936, 944, 1015, 1016, 1033, 1045, 1084, 1097, 1140, 1147, 1151, 1155, 1174, 1197, 1212, 1218, 1234, 1238, 1239, 1256, 1259, 1276, 1345, 1391, 1417, 1418, 1472, 1500, 1944, 1945, 2003, 2011, 2012, 2016, 2068, 2080, 2082])

# %%
table2
# Out:
#                           Publisher Value in Millions of Euros
# 2                    Absa Group Ltd                          5
# 3       Anglo American Platinum Ltd                          1
# 4             Anglogold Ashanti Plc                         29
# 5     Aspen Pharmacare Holdings Ltd                          1
# 6                           AVI Ltd                          7
# ...                             ...                        ...
# 2081                 Bancolombia SA                          7
# 2083  Cia de Minas Buenaventura SAA                          3
# 2084                  Credicorp Ltd                        139
# 2085           Southern Copper Corp                         85
# 2086                         Totaal                    181.555
#
# [2031 rows x 2 columns]

# %%
table2.to_csv("stichting_pensioenfonds_ABP.csv")
